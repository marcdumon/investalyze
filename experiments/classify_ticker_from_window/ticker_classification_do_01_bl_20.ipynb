# %%
# %load_ext autoreload
# %autoreload 2
import sys
from pathlib import Path

sys.path.insert(0, '..')  # dataset.py lives one level up, shared across experiment types
import dataset
import matplotlib.colors as mcolors
import matplotlib.pyplot as plt
import model as model_module
import numpy as np
import pandas as pd
import torch
import train as train_module
from sklearn.metrics import confusion_matrix

from investalyze.analysis import encodings
from investalyze.ingest import storage

plt.rcParams['figure.dpi'] = 130
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
TICKERS = None  # list[str] of specific tickers, int for a random sample of that many, or None for all
UNIVERSE = None  # name of a universe saved by the ticker selector app (data/universes/<name>.csv); overrides TICKERS when set
EXCLUDE_TICKERS = [
    # 'LITX',
    # 'PCG-PD',
    # 'LIFE',
    # 'AKRE',
    # 'BOBS',
    # 'BKMI',
    # 'QBTZ',
    # 'XWIN',
    # 'SHAZ',
    # 'OPENL',
    # 'HOYY',
    # 'JBS',
    # 'NSIT',
]  # tickers to always leave out, regardless of TICKERS or UNIVERSE

SEED = 0  # used when TICKERS is an int, and when VALID_METHOD is 'random'
WINDOW_LENGTH = 30
STRIDE = 15

VALID_FRAC = 0.3
VALID_METHOD = 'random'  # 'recent' = time-based (no leakage) / 'random' = random per-window
TEST_N = 1  # always recent: the last N windows of each ticker

ENCODER = encodings.zscore  # swap by hand: RebaseTo100 / RebaseTo1 / encodings.zscore / encodings.minmax
# ENCODER = encodings.minmax  # swap by hand: RebaseTo100 / RebaseTo1 / encodings.zscore / encodings.minmax
BATCH_SIZE = 1024 * 16
EPOCHS = 300000000000000
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'

HIDDEN = 64
DROPOUT = 0.1
N_BLOCKS = 20  # residual conv blocks (skip connection per block)
KERNEL_START = 3  # kernel size of the stem conv + first residual blocks
KERNEL_END = 9  # kernel size reached by the last residual block (quadratic ramp, odd sizes only)

LR = 1e-3
WEIGHT_DECAY = 0.01  # AdamW L2-ish regularization, applied directly to weights not through the gradient
LR_FACTOR = 0.5  # ReduceLROnPlateau: multiply lr by this on plateau
LR_PATIENCE = 20  # ReduceLROnPlateau: epochs of no valid_loss improvement before reducing lr
LR_METRIC = 'valid'  # 'valid' normally / 'train' when deliberately overfitting to sanity-check capacity

EARLY_STOP_PATIENCE = 100000000  # stop if valid_loss hasn't improved in this many epochs
EVAL_CHECKPOINT = 'valid_loss'  # 'last' / 'train_loss' / 'valid_loss' / 'train_acc' / 'valid_acc'

# %%
DATA_ROOT = Path('../../data')

con = storage.connect(DATA_ROOT, read_only=True)
if UNIVERSE is not None:
    tickers = [t for t in dataset.load_universe(UNIVERSE, DATA_ROOT) if t not in EXCLUDE_TICKERS]
elif isinstance(TICKERS, int):
    tickers = dataset.sample_tickers(con, TICKERS, seed=SEED, exclude=EXCLUDE_TICKERS)
else:
    tickers = TICKERS
series = dataset.get_ohlcv_series(con, tickers, exclude=EXCLUDE_TICKERS)
con.close()
print('tickers used', tickers if tickers is not None else 'ALL')

channels, meta = dataset.build_windows(series, window_length=WINDOW_LENGTH, stride=STRIDE)
print('windows', meta.shape[0], 'across', meta['Ticker'].nunique(), 'tickers')
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# tickers used ALL
# windows 1572103 across 7639 tickers

# %%
train_mask, valid_mask, test_mask = dataset.split_windows(meta, valid_frac=VALID_FRAC, valid_method=VALID_METHOD, test_n=TEST_N, seed=SEED)

labels, tickers_sorted = dataset.encode_labels(meta, train_mask)
n_classes = len(tickers_sorted)

print('train windows', int(train_mask.sum()), 'valid windows', int(valid_mask.sum()), 'test windows', int(test_mask.sum()))
pd.Series(labels[train_mask]).value_counts().sort_index()
# Out:
# train windows 1090044 valid windows 467079 test windows 7387
# 0       327
# 1       755
# 2       159
# 3         3
# 4       215
#        ...
# 7382     35
# 7383    121
# 7384    167
# 7385     17
# 7386    105
# Name: count, Length: 7387, dtype: int64

# %%
X = dataset.encode_windows(channels, ENCODER)
X_train, y_train = X[train_mask], labels[train_mask]
X_valid, y_valid = X[valid_mask], labels[valid_mask]
X_test, y_test = X[test_mask], labels[test_mask]

weights = dataset.class_weights(y_train, n_classes)
train_loader = train_module.make_loader(X_train, y_train, batch_size=BATCH_SIZE, shuffle=True)
valid_loader = train_module.make_loader(X_valid, y_valid, batch_size=BATCH_SIZE, shuffle=False)
test_loader = train_module.make_loader(X_test, y_test, batch_size=BATCH_SIZE, shuffle=False)

# %%
net = model_module.OHLCVClassifierCNN(
    n_channels=5,
    n_classes=n_classes,
    hidden=HIDDEN,
    dropout=DROPOUT,
    n_blocks=N_BLOCKS,
    kernel_start=KERNEL_START,
    kernel_end=KERNEL_END,
).to(DEVICE)
optimizer = torch.optim.AdamW(net.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=LR_FACTOR, patience=LR_PATIENCE)
history = {'train_loss': [], 'valid_loss': [], 'train_acc': [], 'valid_acc': []}
best = train_module.new_best_tracker()

# %%
net
# Out:
# OHLCVClassifierCNN(
#   (stem): Sequential(
#     (0): Conv1d(5, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout1d(p=0.1, inplace=False)
#   )
#   (blocks): Sequential(
#     (0): _ResConvBlock(
#       (net): Sequential(
#         (0): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#         (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Dropout1d(p=0.1, inplace=False)
#       )
#     )
#     (1): _ResConvBlock(
#       (net): Sequential(
#         (0): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#         (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Dropout1d(p=0.1, inplace=False)
#       )
#     )
#     (2): _ResConvBlock(
#       (net): Sequential(
#         (0): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#         (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Dropout1d(p=0.1, inplace=False)
#       )
#     )
#     (3): _ResConvBlock(
#       (net): Sequential(
#         (0): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#         (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Dropout1d(p=0.1, inplace=False)
#       )
#     )
#     (4): _ResConvBlock(
#       (net): Sequential(
#         (0): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#         (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Dropout1d(p=0.1, inplace=False)
#       )
#     )
#     (5): _ResConvBlock(
#       (net): Sequential(
#         (0): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#         (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Dropout1d(p=0.1, inplace=False)
#       )
#     )
#     (6): _ResConvBlock(
#       (net): Sequential(
#         (0): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#         (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Dropout1d(p=0.1, inplace=False)
#       )
#     )
#     (7): _ResConvBlock(
#       (net): Sequential(
#         (0): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#         (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Dropout1d(p=0.1, inplace=False)
#       )
#     )
#     (8): _ResConvBlock(
#       (net): Sequential(
#         (0): Conv1d(64, 64, kernel_size=(5,), stride=(1,), padding=(2,))
#         (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Dropout1d(p=0.1, inplace=False)
#       )
#     )
#     (9): _ResConvBlock(
#       (net): Sequential(
#         (0): Conv1d(64, 64, kernel_size=(5,), stride=(1,), padding=(2,))
#         (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Dropout1d(p=0.1, inplace=False)
#       )
#     )
#     (10): _ResConvBlock(
#       (net): Sequential(
#         (0): Conv1d(64, 64, kernel_size=(5,), stride=(1,), padding=(2,))
#         (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Dropout1d(p=0.1, inplace=False)
#       )
#     )
#     (11): _ResConvBlock(
#       (net): Sequential(
#         (0): Conv1d(64, 64, kernel_size=(5,), stride=(1,), padding=(2,))
#         (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Dropout1d(p=0.1, inplace=False)
#       )
#     )
#     (12): _ResConvBlock(
#       (net): Sequential(
#         (0): Conv1d(64, 64, kernel_size=(5,), stride=(1,), padding=(2,))
#         (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Dropout1d(p=0.1, inplace=False)
#       )
#     )
#     (13): _ResConvBlock(
#       (net): Sequential(
#         (0): Conv1d(64, 64, kernel_size=(7,), stride=(1,), padding=(3,))
#         (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Dropout1d(p=0.1, inplace=False)
#       )
#     )
#     (14): _ResConvBlock(
#       (net): Sequential(
#         (0): Conv1d(64, 64, kernel_size=(7,), stride=(1,), padding=(3,))
#         (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Dropout1d(p=0.1, inplace=False)
#       )
#     )
#     (15): _ResConvBlock(
#       (net): Sequential(
#         (0): Conv1d(64, 64, kernel_size=(7,), stride=(1,), padding=(3,))
#         (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Dropout1d(p=0.1, inplace=False)
#       )
#     )
#     (16): _ResConvBlock(
#       (net): Sequential(
#         (0): Conv1d(64, 64, kernel_size=(7,), stride=(1,), padding=(3,))
#         (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Dropout1d(p=0.1, inplace=False)
#       )
#     )
#     (17): _ResConvBlock(
#       (net): Sequential(
#         (0): Conv1d(64, 64, kernel_size=(9,), stride=(1,), padding=(4,))
#         (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Dropout1d(p=0.1, inplace=False)
#       )
#     )
#     (18): _ResConvBlock(
#       (net): Sequential(
#         (0): Conv1d(64, 64, kernel_size=(9,), stride=(1,), padding=(4,))
#         (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Dropout1d(p=0.1, inplace=False)
#       )
#     )
#   )
#   (last_conv): Sequential(
#     (0): Conv1d(64, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (pool): AdaptiveAvgPool1d(output_size=1)
#   (head): Sequential(
#     (0): Linear(in_features=32, out_features=16, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.1, inplace=False)
#     (3): Linear(in_features=16, out_features=7387, bias=True)
#   )
# )

# %%
CHANGE_LR = False  # set True (and NEW_LR below), then run this cell to change lr mid-training
NEW_LR = 0.1

if CHANGE_LR:
    for g in optimizer.param_groups:
        g['lr'] = NEW_LR
print(f'lr = {optimizer.param_groups[0]["lr"]:.2e}')
# Out:
# lr = 1.00e-03

# %%
print(f'Baseline loss: {np.log(n_classes):.4f} | acc: {1 / n_classes:.4f}')

# re-run this cell (unchanged) to keep training the same net/optimizer for EPOCHS more
history, best = train_module.train_model(
    net,
    train_loader,
    valid_loader,
    optimizer,
    epochs=EPOCHS,
    class_weights=weights,
    n_classes=n_classes,
    device=DEVICE,
    history=history,
    scheduler=scheduler,
    scheduler_metric=LR_METRIC,
    best=best,
    early_stop_patience=EARLY_STOP_PATIENCE,
)
# Out:
# Baseline loss: 8.9075 | acc: 0.0001
# epoch 1/300000000000000  train_loss=8.9194 valid_loss=8.9178 train_acc=0.0001 valid_acc=0.0001 lr=1.00e-03 (t:1/1 - v:1/1)
# epoch 2/300000000000000  train_loss=8.9133 valid_loss=8.9053 train_acc=0.0001 valid_acc=0.0002 lr=1.00e-03 (t:2/2 - v:2/2)
# epoch 3/300000000000000  train_loss=8.8697 valid_loss=8.8359 train_acc=0.0002 valid_acc=0.0003 lr=1.00e-03 (t:3/3 - v:3/3)
# epoch 4/300000000000000  train_loss=8.7625 valid_loss=8.7482 train_acc=0.0002 valid_acc=0.0004 lr=1.00e-03 (t:4/4 - v:4/4)
# epoch 5/300000000000000  train_loss=8.5985 valid_loss=8.5647 train_acc=0.0005 valid_acc=0.0004 lr=1.00e-03 (t:5/5 - v:5/5)
# epoch 6/300000000000000  train_loss=8.4473 valid_loss=8.5735 train_acc=0.0006 valid_acc=0.0005 lr=1.00e-03 (t:6/6 - v:5/6)
# epoch 7/300000000000000  train_loss=8.3399 valid_loss=8.3545 train_acc=0.0007 valid_acc=0.0008 lr=1.00e-03 (t:7/7 - v:7/7)
# epoch 8/300000000000000  train_loss=8.2491 valid_loss=8.2648 train_acc=0.0008 valid_acc=0.0011 lr=1.00e-03 (t:8/8 - v:8/8)
# epoch 9/300000000000000  train_loss=8.1694 valid_loss=8.1514 train_acc=0.0009 valid_acc=0.0013 lr=1.00e-03 (t:9/9 - v:9/9)
# epoch 10/300000000000000  train_loss=8.0970 valid_loss=8.1033 train_acc=0.0011 valid_acc=0.0017 lr=1.00e-03 (t:10/10 - v:10/10)
# epoch 11/300000000000000  train_loss=8.0290 valid_loss=8.0023 train_acc=0.0014 valid_acc=0.0017 lr=1.00e-03 (t:11/11 - v:11/11)
# epoch 12/300000000000000  train_loss=7.9749 valid_loss=8.0063 train_acc=0.0017 valid_acc=0.0015 lr=1.00e-03 (t:12/12 - v:11/11)
# epoch 13/300000000000000  train_loss=7.9294 valid_loss=7.9550 train_acc=0.0017 valid_acc=0.0020 lr=1.00e-03 (t:13/13 - v:13/13)
# epoch 14/300000000000000  train_loss=7.8872 valid_loss=7.8678 train_acc=0.0018 valid_acc=0.0027 lr=1.00e-03 (t:14/14 - v:14/14)
# epoch 15/300000000000000  train_loss=7.8517 valid_loss=7.9291 train_acc=0.0024 valid_acc=0.0020 lr=1.00e-03 (t:15/15 - v:14/14)
# epoch 16/300000000000000  train_loss=7.8179 valid_loss=7.9647 train_acc=0.0027 valid_acc=0.0018 lr=1.00e-03 (t:16/16 - v:14/14)
# epoch 17/300000000000000  train_loss=7.7825 valid_loss=7.8377 train_acc=0.0027 valid_acc=0.0025 lr=1.00e-03 (t:17/16 - v:17/14)
# epoch 18/300000000000000  train_loss=7.7570 valid_loss=7.8341 train_acc=0.0031 valid_acc=0.0029 lr=1.00e-03 (t:18/18 - v:18/18)
# epoch 19/300000000000000  train_loss=7.7275 valid_loss=7.7844 train_acc=0.0032 valid_acc=0.0025 lr=1.00e-03 (t:19/19 - v:19/18)
# epoch 20/300000000000000  train_loss=7.7030 valid_loss=7.7164 train_acc=0.0033 valid_acc=0.0034 lr=1.00e-03 (t:20/20 - v:20/20)
# epoch 21/300000000000000  train_loss=7.6774 valid_loss=7.7524 train_acc=0.0038 valid_acc=0.0031 lr=1.00e-03 (t:21/21 - v:20/20)
# epoch 22/300000000000000  train_loss=7.6591 valid_loss=7.7110 train_acc=0.0040 valid_acc=0.0034 lr=1.00e-03 (t:22/22 - v:22/20)
# epoch 23/300000000000000  train_loss=7.6325 valid_loss=7.6583 train_acc=0.0049 valid_acc=0.0032 lr=1.00e-03 (t:23/23 - v:23/20)
# epoch 24/300000000000000  train_loss=7.6160 valid_loss=7.6499 train_acc=0.0052 valid_acc=0.0039 lr=1.00e-03 (t:24/24 - v:24/24)
# epoch 25/300000000000000  train_loss=7.5914 valid_loss=7.7141 train_acc=0.0049 valid_acc=0.0040 lr=1.00e-03 (t:25/24 - v:24/25)
# epoch 26/300000000000000  train_loss=7.5734 valid_loss=7.7678 train_acc=0.0059 valid_acc=0.0031 lr=1.00e-03 (t:26/26 - v:24/25)
# epoch 27/300000000000000  train_loss=7.5529 valid_loss=7.6014 train_acc=0.0064 valid_acc=0.0039 lr=1.00e-03 (t:27/27 - v:27/25)
# epoch 28/300000000000000  train_loss=7.5328 valid_loss=7.8874 train_acc=0.0077 valid_acc=0.0030 lr=1.00e-03 (t:28/28 - v:27/25)
# epoch 29/300000000000000  train_loss=7.5175 valid_loss=7.6498 train_acc=0.0080 valid_acc=0.0037 lr=1.00e-03 (t:29/29 - v:27/25)
# epoch 30/300000000000000  train_loss=7.5008 valid_loss=7.5632 train_acc=0.0077 valid_acc=0.0043 lr=1.00e-03 (t:30/29 - v:30/30)
# epoch 31/300000000000000  train_loss=7.4862 valid_loss=7.5613 train_acc=0.0094 valid_acc=0.0054 lr=1.00e-03 (t:31/31 - v:31/31)
# epoch 32/300000000000000  train_loss=7.4689 valid_loss=7.7716 train_acc=0.0091 valid_acc=0.0019 lr=1.00e-03 (t:32/31 - v:31/31)
# epoch 33/300000000000000  train_loss=7.4457 valid_loss=7.5781 train_acc=0.0105 valid_acc=0.0049 lr=1.00e-03 (t:33/33 - v:31/31)
# epoch 34/300000000000000  train_loss=7.4470 valid_loss=7.6336 train_acc=0.0108 valid_acc=0.0031 lr=1.00e-03 (t:33/34 - v:31/31)
# epoch 35/300000000000000  train_loss=7.4291 valid_loss=7.5753 train_acc=0.0101 valid_acc=0.0047 lr=1.00e-03 (t:35/34 - v:31/31)
# epoch 36/300000000000000  train_loss=7.4077 valid_loss=7.5893 train_acc=0.0132 valid_acc=0.0051 lr=1.00e-03 (t:36/36 - v:31/31)
# epoch 37/300000000000000  train_loss=7.4016 valid_loss=7.5852 train_acc=0.0124 valid_acc=0.0049 lr=1.00e-03 (t:37/36 - v:31/31)
# epoch 38/300000000000000  train_loss=7.3831 valid_loss=7.5478 train_acc=0.0138 valid_acc=0.0060 lr=1.00e-03 (t:38/38 - v:38/38)
# epoch 39/300000000000000  train_loss=7.3642 valid_loss=7.5431 train_acc=0.0146 valid_acc=0.0062 lr=1.00e-03 (t:39/39 - v:39/39)
# epoch 40/300000000000000  train_loss=7.3578 valid_loss=7.5728 train_acc=0.0141 valid_acc=0.0052 lr=1.00e-03 (t:40/39 - v:39/39)
# epoch 41/300000000000000  train_loss=7.3402 valid_loss=7.6553 train_acc=0.0155 valid_acc=0.0043 lr=1.00e-03 (t:41/41 - v:39/39)
# epoch 42/300000000000000  train_loss=7.3212 valid_loss=7.5029 train_acc=0.0156 valid_acc=0.0052 lr=1.00e-03 (t:42/42 - v:42/39)
# epoch 43/300000000000000  train_loss=7.3125 valid_loss=7.7141 train_acc=0.0173 valid_acc=0.0054 lr=1.00e-03 (t:43/43 - v:42/39)
# epoch 44/300000000000000  train_loss=7.3049 valid_loss=7.6926 train_acc=0.0158 valid_acc=0.0055 lr=1.00e-03 (t:44/43 - v:42/39)
# epoch 45/300000000000000  train_loss=7.2864 valid_loss=7.6324 train_acc=0.0197 valid_acc=0.0043 lr=1.00e-03 (t:45/45 - v:42/39)
# epoch 46/300000000000000  train_loss=7.2779 valid_loss=7.6183 train_acc=0.0194 valid_acc=0.0056 lr=1.00e-03 (t:46/45 - v:42/39)
# epoch 47/300000000000000  train_loss=7.2794 valid_loss=7.6005 train_acc=0.0185 valid_acc=0.0039 lr=1.00e-03 (t:46/45 - v:42/39)
# epoch 48/300000000000000  train_loss=7.2544 valid_loss=7.5945 train_acc=0.0191 valid_acc=0.0053 lr=1.00e-03 (t:48/45 - v:42/39)
# epoch 49/300000000000000  train_loss=7.2453 valid_loss=7.5155 train_acc=0.0211 valid_acc=0.0066 lr=1.00e-03 (t:49/49 - v:42/49)
# epoch 50/300000000000000  train_loss=7.2396 valid_loss=7.5782 train_acc=0.0207 valid_acc=0.0070 lr=1.00e-03 (t:50/49 - v:42/50)
# epoch 51/300000000000000  train_loss=7.2185 valid_loss=7.5512 train_acc=0.0227 valid_acc=0.0069 lr=1.00e-03 (t:51/51 - v:42/50)
# epoch 52/300000000000000  train_loss=7.2082 valid_loss=7.5361 train_acc=0.0244 valid_acc=0.0069 lr=1.00e-03 (t:52/52 - v:42/50)
# epoch 53/300000000000000  train_loss=7.2115 valid_loss=7.5968 train_acc=0.0237 valid_acc=0.0063 lr=1.00e-03 (t:52/52 - v:42/50)
# epoch 54/300000000000000  train_loss=7.1854 valid_loss=7.6541 train_acc=0.0258 valid_acc=0.0064 lr=1.00e-03 (t:54/54 - v:42/50)
# epoch 55/300000000000000  train_loss=7.1752 valid_loss=7.7179 train_acc=0.0253 valid_acc=0.0046 lr=1.00e-03 (t:55/54 - v:42/50)
# epoch 56/300000000000000  train_loss=7.1728 valid_loss=7.5428 train_acc=0.0259 valid_acc=0.0070 lr=1.00e-03 (t:56/56 - v:42/56)
# epoch 57/300000000000000  train_loss=7.1542 valid_loss=7.6739 train_acc=0.0278 valid_acc=0.0067 lr=1.00e-03 (t:57/57 - v:42/56)
# epoch 58/300000000000000  train_loss=7.1553 valid_loss=7.5853 train_acc=0.0270 valid_acc=0.0070 lr=1.00e-03 (t:57/57 - v:42/56)
# epoch 59/300000000000000  train_loss=7.1375 valid_loss=7.5292 train_acc=0.0278 valid_acc=0.0080 lr=1.00e-03 (t:59/59 - v:42/59)
# epoch 60/300000000000000  train_loss=7.1224 valid_loss=7.6237 train_acc=0.0300 valid_acc=0.0060 lr=1.00e-03 (t:60/60 - v:42/59)
# epoch 61/300000000000000  train_loss=7.1132 valid_loss=7.6082 train_acc=0.0312 valid_acc=0.0086 lr=1.00e-03 (t:61/61 - v:42/61)
# epoch 62/300000000000000  train_loss=7.1035 valid_loss=7.6344 train_acc=0.0311 valid_acc=0.0075 lr=1.00e-03 (t:62/61 - v:42/61)
# epoch 63/300000000000000  train_loss=7.0926 valid_loss=7.5682 train_acc=0.0332 valid_acc=0.0087 lr=5.00e-04 (t:63/63 - v:42/63)
# epoch 64/300000000000000  train_loss=7.0644 valid_loss=7.5515 train_acc=0.0346 valid_acc=0.0101 lr=5.00e-04 (t:64/64 - v:42/64)
# epoch 65/300000000000000  train_loss=7.0405 valid_loss=7.5616 train_acc=0.0391 valid_acc=0.0095 lr=5.00e-04 (t:65/65 - v:42/64)
# epoch 66/300000000000000  train_loss=7.0281 valid_loss=7.5574 train_acc=0.0389 valid_acc=0.0097 lr=5.00e-04 (t:66/65 - v:42/64)
# epoch 67/300000000000000  train_loss=7.0168 valid_loss=7.5592 train_acc=0.0406 valid_acc=0.0093 lr=5.00e-04 (t:67/67 - v:42/64)
# epoch 68/300000000000000  train_loss=7.0183 valid_loss=7.5258 train_acc=0.0411 valid_acc=0.0102 lr=5.00e-04 (t:67/68 - v:42/68)
# epoch 69/300000000000000  train_loss=7.0056 valid_loss=7.6091 train_acc=0.0400 valid_acc=0.0088 lr=5.00e-04 (t:69/68 - v:42/68)
# epoch 70/300000000000000  train_loss=7.0082 valid_loss=7.5718 train_acc=0.0403 valid_acc=0.0100 lr=5.00e-04 (t:69/68 - v:42/68)
# epoch 71/300000000000000  train_loss=6.9958 valid_loss=7.5949 train_acc=0.0417 valid_acc=0.0091 lr=5.00e-04 (t:71/71 - v:42/68)
# epoch 72/300000000000000  train_loss=6.9849 valid_loss=7.6295 train_acc=0.0430 valid_acc=0.0094 lr=5.00e-04 (t:72/72 - v:42/68)
# epoch 73/300000000000000  train_loss=6.9829 valid_loss=7.5958 train_acc=0.0438 valid_acc=0.0107 lr=5.00e-04 (t:73/73 - v:42/73)
# epoch 74/300000000000000  train_loss=6.9749 valid_loss=7.5516 train_acc=0.0432 valid_acc=0.0098 lr=5.00e-04 (t:74/73 - v:42/73)
# epoch 75/300000000000000  train_loss=6.9713 valid_loss=7.5578 train_acc=0.0440 valid_acc=0.0103 lr=5.00e-04 (t:75/75 - v:42/73)
# epoch 76/300000000000000  train_loss=6.9672 valid_loss=7.5555 train_acc=0.0450 valid_acc=0.0107 lr=5.00e-04 (t:76/76 - v:42/76)
# epoch 77/300000000000000  train_loss=6.9632 valid_loss=7.5610 train_acc=0.0456 valid_acc=0.0114 lr=5.00e-04 (t:77/77 - v:42/77)
# epoch 78/300000000000000  train_loss=6.9608 valid_loss=7.5487 train_acc=0.0469 valid_acc=0.0105 lr=5.00e-04 (t:78/78 - v:42/77)
# epoch 79/300000000000000  train_loss=6.9568 valid_loss=7.6351 train_acc=0.0475 valid_acc=0.0104 lr=5.00e-04 (t:79/79 - v:42/77)
# epoch 80/300000000000000  train_loss=6.9481 valid_loss=7.6073 train_acc=0.0463 valid_acc=0.0117 lr=5.00e-04 (t:80/79 - v:42/80)
# epoch 81/300000000000000  train_loss=6.9423 valid_loss=7.5582 train_acc=0.0471 valid_acc=0.0115 lr=5.00e-04 (t:81/79 - v:42/80)
# epoch 82/300000000000000  train_loss=6.9402 valid_loss=7.5771 train_acc=0.0459 valid_acc=0.0106 lr=5.00e-04 (t:82/79 - v:42/80)
# epoch 83/300000000000000  train_loss=6.9336 valid_loss=7.4783 train_acc=0.0486 valid_acc=0.0110 lr=5.00e-04 (t:83/83 - v:83/80)
# epoch 84/300000000000000  train_loss=6.9278 valid_loss=7.5770 train_acc=0.0488 valid_acc=0.0111 lr=5.00e-04 (t:84/84 - v:83/80)
# epoch 85/300000000000000  train_loss=6.9302 valid_loss=7.6297 train_acc=0.0497 valid_acc=0.0108 lr=5.00e-04 (t:84/85 - v:83/80)
# epoch 86/300000000000000  train_loss=6.9208 valid_loss=7.6574 train_acc=0.0494 valid_acc=0.0107 lr=5.00e-04 (t:86/85 - v:83/80)
# epoch 87/300000000000000  train_loss=6.9116 valid_loss=7.5879 train_acc=0.0502 valid_acc=0.0107 lr=5.00e-04 (t:87/87 - v:83/80)
# epoch 88/300000000000000  train_loss=6.9039 valid_loss=7.6025 train_acc=0.0518 valid_acc=0.0116 lr=5.00e-04 (t:88/88 - v:83/80)
# epoch 89/300000000000000  train_loss=6.9071 valid_loss=7.5876 train_acc=0.0515 valid_acc=0.0110 lr=5.00e-04 (t:88/88 - v:83/80)
# epoch 90/300000000000000  train_loss=6.9062 valid_loss=7.6333 train_acc=0.0504 valid_acc=0.0121 lr=5.00e-04 (t:88/88 - v:83/90)
# epoch 91/300000000000000  train_loss=6.8869 valid_loss=7.6285 train_acc=0.0526 valid_acc=0.0124 lr=5.00e-04 (t:91/91 - v:83/91)
# epoch 92/300000000000000  train_loss=6.8896 valid_loss=7.6166 train_acc=0.0521 valid_acc=0.0117 lr=5.00e-04 (t:91/91 - v:83/91)
# epoch 93/300000000000000  train_loss=6.8826 valid_loss=7.6941 train_acc=0.0529 valid_acc=0.0120 lr=5.00e-04 (t:93/93 - v:83/91)
# epoch 94/300000000000000  train_loss=6.8827 valid_loss=7.6534 train_acc=0.0533 valid_acc=0.0120 lr=5.00e-04 (t:93/94 - v:83/91)
# epoch 95/300000000000000  train_loss=6.8881 valid_loss=7.6331 train_acc=0.0522 valid_acc=0.0117 lr=5.00e-04 (t:93/94 - v:83/91)
# epoch 96/300000000000000  train_loss=6.8754 valid_loss=7.8318 train_acc=0.0536 valid_acc=0.0106 lr=5.00e-04 (t:96/96 - v:83/91)
# epoch 97/300000000000000  train_loss=6.8692 valid_loss=7.7348 train_acc=0.0546 valid_acc=0.0119 lr=5.00e-04 (t:97/97 - v:83/91)
# epoch 98/300000000000000  train_loss=6.8669 valid_loss=7.6346 train_acc=0.0538 valid_acc=0.0124 lr=5.00e-04 (t:98/97 - v:83/91)
# epoch 99/300000000000000  train_loss=6.8569 valid_loss=7.5573 train_acc=0.0547 valid_acc=0.0111 lr=5.00e-04 (t:99/99 - v:83/91)
# epoch 100/300000000000000  train_loss=6.8546 valid_loss=7.5996 train_acc=0.0550 valid_acc=0.0122 lr=5.00e-04 (t:100/100 - v:83/91)
# epoch 101/300000000000000  train_loss=6.8519 valid_loss=7.5556 train_acc=0.0544 valid_acc=0.0119 lr=5.00e-04 (t:101/100 - v:83/91)
# epoch 102/300000000000000  train_loss=6.8485 valid_loss=7.8095 train_acc=0.0560 valid_acc=0.0108 lr=5.00e-04 (t:102/102 - v:83/91)
# epoch 103/300000000000000  train_loss=6.8445 valid_loss=7.6798 train_acc=0.0565 valid_acc=0.0122 lr=5.00e-04 (t:103/103 - v:83/91)
# epoch 104/300000000000000  train_loss=6.8316 valid_loss=7.7029 train_acc=0.0605 valid_acc=0.0125 lr=2.50e-04 (t:104/104 - v:83/104)
# epoch 105/300000000000000  train_loss=6.8156 valid_loss=7.6637 train_acc=0.0611 valid_acc=0.0128 lr=2.50e-04 (t:105/105 - v:83/105)
# epoch 106/300000000000000  train_loss=6.8146 valid_loss=7.6721 train_acc=0.0603 valid_acc=0.0126 lr=2.50e-04 (t:106/105 - v:83/105)
# epoch 107/300000000000000  train_loss=6.8077 valid_loss=7.6215 train_acc=0.0610 valid_acc=0.0130 lr=2.50e-04 (t:107/105 - v:83/107)
# epoch 108/300000000000000  train_loss=6.8015 valid_loss=7.6666 train_acc=0.0625 valid_acc=0.0132 lr=2.50e-04 (t:108/108 - v:83/108)
# epoch 109/300000000000000  train_loss=6.7853 valid_loss=7.6337 train_acc=0.0641 valid_acc=0.0130 lr=2.50e-04 (t:109/109 - v:83/108)
# epoch 110/300000000000000  train_loss=6.7855 valid_loss=7.6556 train_acc=0.0642 valid_acc=0.0135 lr=2.50e-04 (t:109/110 - v:83/110)
# epoch 111/300000000000000  train_loss=6.7910 valid_loss=7.5989 train_acc=0.0636 valid_acc=0.0129 lr=2.50e-04 (t:109/110 - v:83/110)
# epoch 112/300000000000000  train_loss=6.7884 valid_loss=7.6725 train_acc=0.0641 valid_acc=0.0140 lr=2.50e-04 (t:109/110 - v:83/112)
# epoch 113/300000000000000  train_loss=6.7793 valid_loss=7.6221 train_acc=0.0655 valid_acc=0.0144 lr=2.50e-04 (t:113/113 - v:83/113)
# epoch 114/300000000000000  train_loss=6.7824 valid_loss=7.6219 train_acc=0.0657 valid_acc=0.0138 lr=2.50e-04 (t:113/114 - v:83/113)
# epoch 115/300000000000000  train_loss=6.7774 valid_loss=7.7071 train_acc=0.0649 valid_acc=0.0133 lr=2.50e-04 (t:115/114 - v:83/113)
# epoch 116/300000000000000  train_loss=6.7854 valid_loss=7.6438 train_acc=0.0650 valid_acc=0.0141 lr=2.50e-04 (t:115/114 - v:83/113)
# epoch 117/300000000000000  train_loss=6.7771 valid_loss=7.6591 train_acc=0.0660 valid_acc=0.0143 lr=2.50e-04 (t:117/117 - v:83/113)
# epoch 118/300000000000000  train_loss=6.7721 valid_loss=7.6554 train_acc=0.0683 valid_acc=0.0137 lr=2.50e-04 (t:118/118 - v:83/113)
# epoch 119/300000000000000  train_loss=6.7607 valid_loss=7.7104 train_acc=0.0681 valid_acc=0.0133 lr=2.50e-04 (t:119/118 - v:83/113)
# epoch 120/300000000000000  train_loss=6.7658 valid_loss=7.6197 train_acc=0.0659 valid_acc=0.0140 lr=2.50e-04 (t:119/118 - v:83/113)
# epoch 121/300000000000000  train_loss=6.7662 valid_loss=7.8025 train_acc=0.0661 valid_acc=0.0134 lr=2.50e-04 (t:119/118 - v:83/113)
# epoch 122/300000000000000  train_loss=6.7690 valid_loss=7.7630 train_acc=0.0657 valid_acc=0.0134 lr=2.50e-04 (t:119/118 - v:83/113)
# epoch 123/300000000000000  train_loss=6.7561 valid_loss=7.7387 train_acc=0.0655 valid_acc=0.0133 lr=2.50e-04 (t:123/118 - v:83/113)
# epoch 124/300000000000000  train_loss=6.7575 valid_loss=7.8407 train_acc=0.0675 valid_acc=0.0128 lr=2.50e-04 (t:123/118 - v:83/113)
# epoch 125/300000000000000  train_loss=6.7586 valid_loss=7.7389 train_acc=0.0687 valid_acc=0.0131 lr=1.25e-04 (t:123/125 - v:83/113)
# epoch 126/300000000000000  train_loss=6.7449 valid_loss=7.7208 train_acc=0.0684 valid_acc=0.0138 lr=1.25e-04 (t:126/125 - v:83/113)
# epoch 127/300000000000000  train_loss=6.7453 valid_loss=7.6872 train_acc=0.0684 valid_acc=0.0143 lr=1.25e-04 (t:126/125 - v:83/113)
# epoch 128/300000000000000  train_loss=6.7470 valid_loss=7.7464 train_acc=0.0699 valid_acc=0.0143 lr=1.25e-04 (t:126/128 - v:83/113)
# epoch 129/300000000000000  train_loss=6.7411 valid_loss=7.6958 train_acc=0.0708 valid_acc=0.0143 lr=1.25e-04 (t:129/129 - v:83/113)
# epoch 130/300000000000000  train_loss=6.7347 valid_loss=7.7447 train_acc=0.0693 valid_acc=0.0138 lr=1.25e-04 (t:130/129 - v:83/113)
# epoch 131/300000000000000  train_loss=6.7361 valid_loss=7.6706 train_acc=0.0698 valid_acc=0.0139 lr=1.25e-04 (t:130/129 - v:83/113)
# epoch 132/300000000000000  train_loss=6.7397 valid_loss=7.6913 train_acc=0.0692 valid_acc=0.0141 lr=1.25e-04 (t:130/129 - v:83/113)
# epoch 133/300000000000000  train_loss=6.7274 valid_loss=7.6828 train_acc=0.0704 valid_acc=0.0147 lr=1.25e-04 (t:133/129 - v:83/133)
# epoch 134/300000000000000  train_loss=6.7220 valid_loss=7.7048 train_acc=0.0720 valid_acc=0.0139 lr=1.25e-04 (t:134/134 - v:83/133)
# epoch 135/300000000000000  train_loss=6.7227 valid_loss=7.7043 train_acc=0.0718 valid_acc=0.0142 lr=1.25e-04 (t:134/134 - v:83/133)
# epoch 136/300000000000000  train_loss=6.7259 valid_loss=7.6993 train_acc=0.0713 valid_acc=0.0140 lr=1.25e-04 (t:134/134 - v:83/133)
# epoch 137/300000000000000  train_loss=6.7252 valid_loss=7.7423 train_acc=0.0707 valid_acc=0.0147 lr=1.25e-04 (t:134/134 - v:83/133)
# epoch 138/300000000000000  train_loss=6.7251 valid_loss=7.7473 train_acc=0.0723 valid_acc=0.0143 lr=1.25e-04 (t:134/138 - v:83/133)
# epoch 139/300000000000000  train_loss=6.7338 valid_loss=7.6833 train_acc=0.0703 valid_acc=0.0145 lr=1.25e-04 (t:134/138 - v:83/133)
# epoch 140/300000000000000  train_loss=6.7281 valid_loss=7.7619 train_acc=0.0701 valid_acc=0.0146 lr=1.25e-04 (t:134/138 - v:83/133)
# epoch 141/300000000000000  train_loss=6.7206 valid_loss=7.6937 train_acc=0.0707 valid_acc=0.0147 lr=1.25e-04 (t:141/138 - v:83/133)
# epoch 142/300000000000000  train_loss=6.7257 valid_loss=7.6706 train_acc=0.0705 valid_acc=0.0142 lr=1.25e-04 (t:141/138 - v:83/133)
# epoch 143/300000000000000  train_loss=6.7197 valid_loss=7.7040 train_acc=0.0707 valid_acc=0.0141 lr=1.25e-04 (t:143/138 - v:83/133)
# epoch 144/300000000000000  train_loss=6.7194 valid_loss=7.7268 train_acc=0.0721 valid_acc=0.0141 lr=1.25e-04 (t:144/138 - v:83/133)
# epoch 145/300000000000000  train_loss=6.7267 valid_loss=7.6919 train_acc=0.0686 valid_acc=0.0148 lr=1.25e-04 (t:144/138 - v:83/145)
# epoch 146/300000000000000  train_loss=6.7159 valid_loss=7.7446 train_acc=0.0728 valid_acc=0.0144 lr=6.25e-05 (t:146/146 - v:83/145)
# epoch 147/300000000000000  train_loss=6.7145 valid_loss=7.7141 train_acc=0.0708 valid_acc=0.0150 lr=6.25e-05 (t:147/146 - v:83/147)
# epoch 148/300000000000000  train_loss=6.7166 valid_loss=7.7181 train_acc=0.0722 valid_acc=0.0145 lr=6.25e-05 (t:147/146 - v:83/147)
# epoch 149/300000000000000  train_loss=6.7195 valid_loss=7.6957 train_acc=0.0706 valid_acc=0.0144 lr=6.25e-05 (t:147/146 - v:83/147)
# epoch 150/300000000000000  train_loss=6.7163 valid_loss=7.7114 train_acc=0.0720 valid_acc=0.0141 lr=6.25e-05 (t:147/146 - v:83/147)
# epoch 151/300000000000000  train_loss=6.7099 valid_loss=7.7638 train_acc=0.0707 valid_acc=0.0142 lr=6.25e-05 (t:151/146 - v:83/147)
# epoch 152/300000000000000  train_loss=6.7008 valid_loss=7.7225 train_acc=0.0733 valid_acc=0.0144 lr=6.25e-05 (t:152/152 - v:83/147)
# epoch 153/300000000000000  train_loss=6.7058 valid_loss=7.7071 train_acc=0.0740 valid_acc=0.0150 lr=6.25e-05 (t:152/153 - v:83/147)
# epoch 154/300000000000000  train_loss=6.7102 valid_loss=7.7354 train_acc=0.0725 valid_acc=0.0147 lr=6.25e-05 (t:152/153 - v:83/147)
# epoch 155/300000000000000  train_loss=6.7084 valid_loss=7.7157 train_acc=0.0722 valid_acc=0.0148 lr=6.25e-05 (t:152/153 - v:83/147)
# epoch 156/300000000000000  train_loss=6.7027 valid_loss=7.7483 train_acc=0.0733 valid_acc=0.0148 lr=6.25e-05 (t:152/153 - v:83/147)
# epoch 157/300000000000000  train_loss=6.7029 valid_loss=7.7528 train_acc=0.0726 valid_acc=0.0146 lr=6.25e-05 (t:152/153 - v:83/147)
# epoch 158/300000000000000  train_loss=6.7067 valid_loss=7.7359 train_acc=0.0732 valid_acc=0.0144 lr=6.25e-05 (t:152/153 - v:83/147)
# epoch 159/300000000000000  train_loss=6.6978 valid_loss=7.7362 train_acc=0.0739 valid_acc=0.0149 lr=6.25e-05 (t:159/153 - v:83/147)
# epoch 160/300000000000000  train_loss=6.7021 valid_loss=7.7425 train_acc=0.0729 valid_acc=0.0146 lr=6.25e-05 (t:159/153 - v:83/147)
# epoch 161/300000000000000  train_loss=6.6956 valid_loss=7.7385 train_acc=0.0752 valid_acc=0.0147 lr=6.25e-05 (t:161/161 - v:83/147)
# epoch 162/300000000000000  train_loss=6.6919 valid_loss=7.7246 train_acc=0.0736 valid_acc=0.0144 lr=6.25e-05 (t:162/161 - v:83/147)
# epoch 163/300000000000000  train_loss=6.7008 valid_loss=7.7554 train_acc=0.0721 valid_acc=0.0147 lr=6.25e-05 (t:162/161 - v:83/147)
# epoch 164/300000000000000  train_loss=6.7004 valid_loss=7.7780 train_acc=0.0717 valid_acc=0.0150 lr=6.25e-05 (t:162/161 - v:83/147)
# epoch 165/300000000000000  train_loss=6.6962 valid_loss=7.7418 train_acc=0.0745 valid_acc=0.0148 lr=6.25e-05 (t:162/161 - v:83/147)
# epoch 166/300000000000000  train_loss=6.6957 valid_loss=7.7271 train_acc=0.0713 valid_acc=0.0149 lr=6.25e-05 (t:162/161 - v:83/147)
# epoch 167/300000000000000  train_loss=6.6931 valid_loss=7.7788 train_acc=0.0737 valid_acc=0.0148 lr=3.13e-05 (t:162/161 - v:83/147)
# epoch 168/300000000000000  train_loss=6.6894 valid_loss=7.7628 train_acc=0.0760 valid_acc=0.0147 lr=3.13e-05 (t:168/168 - v:83/147)
# epoch 169/300000000000000  train_loss=6.6920 valid_loss=7.7386 train_acc=0.0750 valid_acc=0.0147 lr=3.13e-05 (t:168/168 - v:83/147)
# epoch 170/300000000000000  train_loss=6.6946 valid_loss=7.7388 train_acc=0.0747 valid_acc=0.0144 lr=3.13e-05 (t:168/168 - v:83/147)
# epoch 171/300000000000000  train_loss=6.6926 valid_loss=7.7351 train_acc=0.0734 valid_acc=0.0146 lr=3.13e-05 (t:168/168 - v:83/147)
# epoch 172/300000000000000  train_loss=6.6945 valid_loss=7.7462 train_acc=0.0721 valid_acc=0.0146 lr=3.13e-05 (t:168/168 - v:83/147)
# epoch 173/300000000000000  train_loss=6.6881 valid_loss=7.7466 train_acc=0.0758 valid_acc=0.0149 lr=3.13e-05 (t:173/168 - v:83/147)
# epoch 174/300000000000000  train_loss=6.6935 valid_loss=7.7493 train_acc=0.0738 valid_acc=0.0142 lr=3.13e-05 (t:173/168 - v:83/147)
# epoch 175/300000000000000  train_loss=6.6892 valid_loss=7.7254 train_acc=0.0762 valid_acc=0.0147 lr=3.13e-05 (t:173/175 - v:83/147)
# epoch 176/300000000000000  train_loss=6.6899 valid_loss=7.7355 train_acc=0.0747 valid_acc=0.0145 lr=3.13e-05 (t:173/175 - v:83/147)
# epoch 177/300000000000000  train_loss=6.6925 valid_loss=7.7465 train_acc=0.0748 valid_acc=0.0144 lr=3.13e-05 (t:173/175 - v:83/147)
# epoch 178/300000000000000  train_loss=6.7003 valid_loss=7.7356 train_acc=0.0720 valid_acc=0.0149 lr=3.13e-05 (t:173/175 - v:83/147)
# epoch 179/300000000000000  train_loss=6.6932 valid_loss=7.7388 train_acc=0.0743 valid_acc=0.0146 lr=3.13e-05 (t:173/175 - v:83/147)
# epoch 180/300000000000000  train_loss=6.6896 valid_loss=7.7675 train_acc=0.0739 valid_acc=0.0149 lr=3.13e-05 (t:173/175 - v:83/147)
# epoch 181/300000000000000  train_loss=6.6910 valid_loss=7.7402 train_acc=0.0742 valid_acc=0.0148 lr=3.13e-05 (t:173/175 - v:83/147)
# epoch 182/300000000000000  train_loss=6.6869 valid_loss=7.7391 train_acc=0.0737 valid_acc=0.0148 lr=3.13e-05 (t:182/175 - v:83/147)
# epoch 183/300000000000000  train_loss=6.6837 valid_loss=7.7408 train_acc=0.0753 valid_acc=0.0148 lr=3.13e-05 (t:183/175 - v:83/147)
# epoch 184/300000000000000  train_loss=6.6863 valid_loss=7.7457 train_acc=0.0744 valid_acc=0.0153 lr=3.13e-05 (t:183/175 - v:83/184)
# epoch 185/300000000000000  train_loss=6.6859 valid_loss=7.7499 train_acc=0.0748 valid_acc=0.0152 lr=3.13e-05 (t:183/175 - v:83/184)
# epoch 186/300000000000000  train_loss=6.6818 valid_loss=7.7558 train_acc=0.0777 valid_acc=0.0146 lr=3.13e-05 (t:186/186 - v:83/184)
# epoch 187/300000000000000  train_loss=6.6871 valid_loss=7.7303 train_acc=0.0755 valid_acc=0.0155 lr=3.13e-05 (t:186/186 - v:83/187)
# epoch 188/300000000000000  train_loss=6.6827 valid_loss=7.7382 train_acc=0.0765 valid_acc=0.0151 lr=1.56e-05 (t:186/186 - v:83/187)
# epoch 189/300000000000000  train_loss=6.6845 valid_loss=7.7500 train_acc=0.0746 valid_acc=0.0150 lr=1.56e-05 (t:186/186 - v:83/187)
# epoch 190/300000000000000  train_loss=6.6792 valid_loss=7.7443 train_acc=0.0768 valid_acc=0.0147 lr=1.56e-05 (t:190/186 - v:83/187)
# epoch 191/300000000000000  train_loss=6.6817 valid_loss=7.7480 train_acc=0.0754 valid_acc=0.0144 lr=1.56e-05 (t:190/186 - v:83/187)
# epoch 192/300000000000000  train_loss=6.6767 valid_loss=7.7480 train_acc=0.0766 valid_acc=0.0145 lr=1.56e-05 (t:192/186 - v:83/187)
# epoch 193/300000000000000  train_loss=6.6795 valid_loss=7.7560 train_acc=0.0764 valid_acc=0.0146 lr=1.56e-05 (t:192/186 - v:83/187)
# epoch 194/300000000000000  train_loss=6.6832 valid_loss=7.7518 train_acc=0.0747 valid_acc=0.0145 lr=1.56e-05 (t:192/186 - v:83/187)
# epoch 195/300000000000000  train_loss=6.6806 valid_loss=7.7482 train_acc=0.0761 valid_acc=0.0151 lr=1.56e-05 (t:192/186 - v:83/187)
# epoch 196/300000000000000  train_loss=6.6881 valid_loss=7.7563 train_acc=0.0759 valid_acc=0.0146 lr=1.56e-05 (t:192/186 - v:83/187)
# epoch 197/300000000000000  train_loss=6.6799 valid_loss=7.7531 train_acc=0.0761 valid_acc=0.0144 lr=1.56e-05 (t:192/186 - v:83/187)
# epoch 198/300000000000000  train_loss=6.6920 valid_loss=7.7427 train_acc=0.0743 valid_acc=0.0148 lr=1.56e-05 (t:192/186 - v:83/187)
# epoch 199/300000000000000  train_loss=6.6845 valid_loss=7.7503 train_acc=0.0744 valid_acc=0.0148 lr=1.56e-05 (t:192/186 - v:83/187)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 4
#       1 print(f'Baseline loss: {np.log(n_classes):.4f} | acc: {1 / n_classes:.4f}')
#       2
#       3 # re-run this cell (unchanged) to keep training the same net/optimizer for EPOCHS more
# ----> 4 history, best = train_module.train_model(
#       5     net,
#       6     train_loader,
#       7     valid_loader,
#
# File /mnt/Dev/active_python_projects/investalyze/experiments/ticker_classification/train.py:71, in train_model(model, train_loader, valid_loader, optimizer, epochs, class_weights, n_classes, device, history, scheduler, scheduler_metric, best, early_stop_patience)
#      69 loss.backward()
#      70 optimizer.step()
# ---> 71 train_loss += loss.item() * len(yb)
#      72 train_preds.append(logits.argmax(1).detach().cpu())
#      73 train_labels.append(yb.cpu())
#
# KeyboardInterrupt:

# %%
#   epoch 50/60  train_loss=7.2227 valid_loss=7.7150 train_acc=0.0241 valid_acc=0.0056 lr=1.00e-03 (t:50/50 - v:45/48)
#   epoch 51/60  train_loss=7.2156 valid_loss=7.7053 train_acc=0.0239 valid_acc=0.0068 lr=1.00e-03 (t:51/50 - v:45/51)
#   epoch 52/60  train_loss=7.2043 valid_loss=7.6690 train_acc=0.0246 valid_acc=0.0050 lr=1.00e-03 (t:52/52 - v:45/51)
#   epoch 53/60  train_loss=7.1736 valid_loss=7.6221 train_acc=0.0266 valid_acc=0.0066 lr=1.00e-03 (t:53/53 - v:45/51)
#   epoch 54/60  train_loss=7.1683 valid_loss=7.8851 train_acc=0.0279 valid_acc=0.0048 lr=1.00e-03 (t:54/54 - v:45/51)
#   ...
#   epoch 57/60  train_loss=7.1345 valid_loss=7.5894 train_acc=0.0288 valid_acc=0.0076 lr=1.00e-03 (t:57/56 - v:45/57)
#   epoch 58/60  train_loss=7.1061 valid_loss=7.9307 train_acc=0.0317 valid_acc=0.0058 lr=1.00e-03 (t:58/58 - v:45/57)
#   epoch 59/60  train_loss=7.0988 valid_loss=7.6622 train_acc=0.0328 valid_acc=0.0077 lr=1.00e-03 (t:59/59 - v:45/59)
#   epoch 60/60  train_loss=7.0810 valid_loss=7.6628 train_acc=0.0357 valid_acc=0.0072 lr=1.00e-03 (t:60/60 - v:45/59)

# %%
for metric_name, info in best.items():
    print(f'best {metric_name}: epoch {info["epoch"] + 1}  value={info["value"]:.4f}')
# Out:
# best train_loss: epoch 192  value=6.6767
# best valid_loss: epoch 83  value=7.4783
# best train_acc: epoch 186  value=0.0777
# best valid_acc: epoch 187  value=0.0155

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))
axes[0].plot(history['train_loss'][10:], label='train')
axes[0].plot(history['valid_loss'][10:], label='valid')
axes[0].set_title('loss')
axes[0].legend()
axes[1].plot(history['train_acc'], label='train')
axes[1].plot(history['valid_acc'], label='valid')
axes[1].axhline(1 / n_classes, color='gray', linestyle='--', label='random baseline')
axes[1].set_title('macro-accuracy')
axes[1].legend()
plt.tight_layout()
plt.show()

# %%
if EVAL_CHECKPOINT != 'last':
    ckpt = best[EVAL_CHECKPOINT]
    net.load_state_dict(ckpt['state'])
    print(f'loaded {EVAL_CHECKPOINT} checkpoint from epoch {ckpt["epoch"] + 1}  value={ckpt["value"]:.4f}')
else:
    print('using last-epoch weights')
# Out:
# loaded valid_loss checkpoint from epoch 83  value=7.4783

# %%
valid_preds, valid_true = train_module.predict(net, valid_loader, DEVICE)
cm_valid = confusion_matrix(valid_true, valid_preds, labels=range(n_classes))
row_sums = cm_valid.sum(axis=1, keepdims=True)
cm_valid_norm = np.divide(cm_valid, row_sums, out=np.zeros_like(cm_valid, dtype=float), where=row_sums != 0)

fig, ax = plt.subplots(figsize=(6, 6))
im = ax.imshow(cm_valid_norm, cmap='viridis', norm=mcolors.PowerNorm(gamma=0.4, vmin=0, vmax=1), interpolation='nearest')
if n_classes <= 40:
    ax.set_xticks(range(n_classes))
    ax.set_xticklabels(tickers_sorted, rotation=90)
    ax.set_yticks(range(n_classes))
    ax.set_yticklabels(tickers_sorted)
else:
    ax.set_xticks([])
    ax.set_yticks([])
ax.set_xlabel('predicted')
ax.set_ylabel('true')
ax.set_title('valid set (row-normalized, gamma=0.4)')
plt.colorbar(im, label='fraction of true class')
plt.tight_layout()
plt.show()

# %%
cm_valid_offdiag = cm_valid.copy()
np.fill_diagonal(cm_valid_offdiag, 0)
i_idx, j_idx = np.nonzero(cm_valid_offdiag)
counts = cm_valid_offdiag[i_idx, j_idx]
order = np.argsort(-counts)[:15]
valid_pairs = [(tickers_sorted[i], tickers_sorted[j], int(c)) for i, j, c in zip(i_idx[order], j_idx[order], counts[order])]
valid_pairs
# Out:
# [('TM', 'HSBC', 52),
#  ('DIS', 'BLLN', 44),
#  ('PPG', 'AKRE', 37),
#  ('HMC', 'HSBC', 36),
#  ('HPQ', 'BLLN', 36),
#  ('KO', 'BLLN', 36),
#  ('KB', 'HSBC', 36),
#  ('DB', 'HSBC', 34),
#  ('IBM', 'BLLN', 34),
#  ('TT', 'AKRE', 33),
#  ('BA', 'BLLN', 32),
#  ('IEX', 'AKRE', 32),
#  ('BCS', 'HSBC', 32),
#  ('ING', 'HSBC', 32),
#  ('AME', 'AKRE', 31)]

# %%
preds, y_true = train_module.predict(net, test_loader, DEVICE)
test_acc = (preds == y_true).mean()
test_macro_acc = train_module.macro_accuracy(torch.tensor(preds), torch.tensor(y_true), n_classes)
print(f'test accuracy={test_acc:.3f}  macro-accuracy={test_macro_acc:.3f}')
cm = confusion_matrix(y_true, preds, labels=range(n_classes))
row_sums = cm.sum(axis=1, keepdims=True)
cm_norm = np.divide(cm, row_sums, out=np.zeros_like(cm, dtype=float), where=row_sums != 0)

fig, ax = plt.subplots(figsize=(6, 6))
im = ax.imshow(cm_norm, cmap='viridis', norm=mcolors.PowerNorm(gamma=0.4, vmin=0, vmax=1), interpolation='nearest')
if n_classes <= 40:
    ax.set_xticks(range(n_classes))
    ax.set_xticklabels(tickers_sorted, rotation=90)
    ax.set_yticks(range(n_classes))
    ax.set_yticklabels(tickers_sorted)
else:
    ax.set_xticks([])
    ax.set_yticks([])
ax.set_xlabel('predicted')
ax.set_ylabel('true')
ax.set_title('test set (row-normalized, gamma=0.4)')
plt.colorbar(im, label='fraction of true class')
plt.tight_layout()
plt.show()
# Out:
# test accuracy=0.004  macro-accuracy=0.004

# %%
cm_offdiag = cm.copy()
np.fill_diagonal(cm_offdiag, 0)
i_idx, j_idx = np.nonzero(cm_offdiag)
counts = cm_offdiag[i_idx, j_idx]
order = np.argsort(-counts)[:150]
pairs = [(tickers_sorted[i], tickers_sorted[j], int(c)) for i, j, c in zip(i_idx[order], j_idx[order], counts[order])]
pairs
# Out:
# [('A', 'LW', 1),
#  ('AA', 'COIN', 1),
#  ('AACG', 'ZTG', 1),
#  ('AAEQ', 'XOEX', 1),
#  ('AAL', 'RGTZ', 1),
#  ('AAME', 'GIPR', 1),
#  ('AAMI', 'CRGY', 1),
#  ('AAOI', 'FRMI', 1),
#  ('AAON', 'PINS', 1),
#  ('AAP', 'BROS', 1),
#  ('AAPG', 'MMSD', 1),
#  ('AAPL', 'SFD', 1),
#  ('AAPW', 'RVLV', 1),
#  ('AARD', 'STRZ', 1),
#  ('AAT', 'LGN', 1),
#  ('AAUC', 'PARK', 1),
#  ('AB', 'AEBI', 1),
#  ('ABAT', 'SEV', 1),
#  ('ABBV', 'GEV', 1),
#  ('ABCB', 'ONTO', 1),
#  ('ABCL', 'EXK', 1),
#  ('ABEO', 'SOBO', 1),
#  ('ABEV', 'VEXC', 1),
#  ('ABFL', 'CGNG', 1),
#  ('ABG', 'SFD', 1),
#  ('ABLD', 'WAMA', 1),
#  ('ABLG', 'ZCBC', 1),
#  ('ABLS', 'ZHOG', 1),
#  ('ABLV', 'BCHT', 1),
#  ('ABM', 'NXT', 1),
#  ('ABNB', 'HTFL', 1),
#  ('ABNG', 'PCG-PC', 1),
#  ('ABNY', 'DLXY', 1),
#  ('ABOS', 'BLLN', 1),
#  ('ABOT', 'HBTC', 1),
#  ('ABR', 'DNUT', 1),
#  ('ABR-PD', 'YSXT', 1),
#  ('ABR-PE', 'INTS', 1),
#  ('ABR-PF', 'RTACW', 1),
#  ('ABSI', 'ARM', 1),
#  ('ABT', 'LGN', 1),
#  ('ABTC', 'RGTU', 1),
#  ('ABTS', 'TDIC', 1),
#  ('ABUS', 'ALMU', 1),
#  ('ABVC', 'ALMU', 1),
#  ('ABVE', 'JAGU', 1),
#  ('ABVX', 'ADAM', 1),
#  ('ABX', 'SOLV', 1),
#  ('ABXB', 'ZCBG', 1),
#  ('ABXL', 'AIRTP', 1),
#  ('ACA', 'PRG', 1),
#  ('ACAD', 'HTFL', 1),
#  ('ACB', 'EQPT', 1),
#  ('ACCL', 'IINNW', 1),
#  ('ACCO', 'CBLL', 1),
#  ('ACCS', 'BWBBP', 1),
#  ('ACDC', 'VWAV', 1),
#  ('ACEI', 'CAIQ', 1),
#  ('ACEL', 'GEV', 1),
#  ('ACEP', 'EDGI', 1),
#  ('ACET', 'EMAT', 1),
#  ('ACFN', 'GGT-PE', 1),
#  ('ACGL', 'JMSB', 1),
#  ('ACGLN', 'PSBD', 1),
#  ('ACGLO', 'BOLD', 1),
#  ('ACGR', 'FLAG', 1),
#  ('ACH', 'NMAX', 1),
#  ('ACHC', 'TBBB', 1),
#  ('ACHR', 'ABCL', 1),
#  ('ACHV', 'EQPT', 1),
#  ('ACI', 'LDI', 1),
#  ('ACIC', 'XWIN', 1),
#  ('ACII', 'GAING', 1),
#  ('ACIU', 'BLLN', 1),
#  ('ACIW', 'CORD', 1),
#  ('ACKY', 'JAJL', 1),
#  ('ACLC', 'EZMO', 1),
#  ('ACLO', 'TRSY', 1),
#  ('ACLS', 'RGTZ', 1),
#  ('ACLX', 'FCRX', 1),
#  ('ACM', 'MDLN', 1),
#  ('ACMR', 'BABA', 1),
#  ('ACN', 'CORD', 1),
#  ('ACNB', 'FVR', 1),
#  ('ACNT', 'XWIN', 1),
#  ('ACOG', 'PARK', 1),
#  ('ACON', 'NCT', 1),
#  ('ACP', 'DHY', 1),
#  ('ACP-PA', 'PMTR', 1),
#  ('ACR', 'ARX', 1),
#  ('ACR-PC', 'GGT-PE', 1),
#  ('ACR-PD', 'OPP-PB', 1),
#  ('ACRE', 'AKRE', 1),
#  ('ACRS', 'ADUS', 1),
#  ('ACRV', 'EMAT', 1),
#  ('ACT', 'DTM', 1),
#  ('ACTG', 'STRZ', 1),
#  ('ACTU', 'CABR', 1),
#  ('ACU', 'TPCS', 1),
#  ('ACV', 'PRIF-PK', 1),
#  ('ACVA', 'AORT', 1),
#  ('ACVT', 'LLDR', 1),
#  ('ACVU', 'XLSI', 1),
#  ('ACXP', 'DGNX', 1),
#  ('ACYN', 'FTNY', 1),
#  ('AD', 'NMFCZ', 1),
#  ('ADAG', 'ODYS', 1),
#  ('ADAM', 'RELY', 1),
#  ('ADAMG', 'TRINZ', 1),
#  ('ADAMH', 'MFAO', 1),
#  ('ADAMI', 'XOMAP', 1),
#  ('ADAML', 'GGT-PE', 1),
#  ('ADAMM', 'FCRX', 1),
#  ('ADAMN', 'GGT-PE', 1),
#  ('ADAMO', 'FTCA', 1),
#  ('ADAMZ', 'PRIF-PK', 1),
#  ('ADBE', 'CRCL', 1),
#  ('ADC', 'TFC-PO', 1),
#  ('ADC-PA', 'MGF', 1),
#  ('ADCT', 'GUTS', 1),
#  ('ADEA', 'EVGN', 1),
#  ('ADGM', 'GMHS', 1),
#  ('ADI', 'IVES', 1),
#  ('ADIL', 'TJGC', 1),
#  ('ADM', 'SLDE', 1),
#  ('ADMA', 'MH', 1),
#  ('ADNT', 'KNF', 1),
#  ('ADP', 'RGTZ', 1),
#  ('ADPT', 'BRCB', 1),
#  ('ADSE', 'WVVIP', 1),
#  ('ADSK', 'BMNR', 1),
#  ('ADT', 'NNN', 1),
#  ('ADTN', 'TUYA', 1),
#  ('ADTX', 'CYAB', 1),
#  ('ADUR', 'FRMI', 1),
#  ('ADUS', 'ARX', 1),
#  ('ADV', 'BLLN', 1),
#  ('ADVB', 'MEGL', 1),
#  ('ADX', 'IYRI', 1),
#  ('ADXN', 'PHAR', 1),
#  ('AEBI', 'LLYVK', 1),
#  ('AEC', 'RGTU', 1),
#  ('AEE', 'AKRE', 1),
#  ('AEF', 'GDXY', 1),
#  ('AEFC', 'HIMU', 1),
#  ('AEG', 'TSCM', 1),
#  ('AEHL', 'PMAX', 1),
#  ('AEHR', 'WPM', 1),
#  ('AEI', 'ANTA', 1),
#  ('AEIS', 'PBR-A', 1)]

# %%
def worst_predicted(cm_offdiag, top=20):
    fp_counts = cm_offdiag.sum(axis=0)  # column sums: how often each ticker is wrongly predicted
    n_sources = (cm_offdiag > 0).sum(axis=0)  # distinct true tickers wrongly predicted as this one
    order = np.argsort(-fp_counts)[:top]
    return order, fp_counts, n_sources


for name, offdiag in [('valid', cm_valid_offdiag), ('test', cm_offdiag)]:
    order, fp_counts, n_sources = worst_predicted(offdiag)
    print(f'{name}:')
    for idx in order:
        pct_sources = n_sources[idx] / n_classes * 100
        print(
            f'  {tickers_sorted[idx]:>8}  wrongly predicted {int(fp_counts[idx])} times, '
            f'from {int(n_sources[idx])} different tickers ({pct_sources:.1f}% of all tickers)'
        )
    print()
# Out:
# valid:
#       AKRE  wrongly predicted 15905 times, from 2436 different tickers (33.0% of all tickers)
#        WBI  wrongly predicted 6773 times, from 2244 different tickers (30.4% of all tickers)
#       BLLN  wrongly predicted 6634 times, from 2316 different tickers (31.4% of all tickers)
#        ARX  wrongly predicted 6461 times, from 2130 different tickers (28.8% of all tickers)
#        MWH  wrongly predicted 5981 times, from 2071 different tickers (28.0% of all tickers)
#         SI  wrongly predicted 5854 times, from 1948 different tickers (26.4% of all tickers)
#      GLIBK  wrongly predicted 5122 times, from 1890 different tickers (25.6% of all tickers)
#        GEV  wrongly predicted 5000 times, from 1648 different tickers (22.3% of all tickers)
#       WLTH  wrongly predicted 4780 times, from 1936 different tickers (26.2% of all tickers)
#       IYRI  wrongly predicted 4272 times, from 1304 different tickers (17.7% of all tickers)
#      LLYVK  wrongly predicted 3788 times, from 1565 different tickers (21.2% of all tickers)
#       HTFL  wrongly predicted 3616 times, from 1839 different tickers (24.9% of all tickers)
#       MAZE  wrongly predicted 3551 times, from 1470 different tickers (19.9% of all tickers)
#       XWIN  wrongly predicted 3293 times, from 1738 different tickers (23.5% of all tickers)
#       VSNT  wrongly predicted 3233 times, from 1625 different tickers (22.0% of all tickers)
#        CBC  wrongly predicted 3229 times, from 1618 different tickers (21.9% of all tickers)
#       ALMU  wrongly predicted 3064 times, from 1644 different tickers (22.3% of all tickers)
#       ANTA  wrongly predicted 3019 times, from 1396 different tickers (18.9% of all tickers)
#       NUCL  wrongly predicted 2857 times, from 1413 different tickers (19.1% of all tickers)
#        SFD  wrongly predicted 2788 times, from 1486 different tickers (20.1% of all tickers)
#
# test:
#       AKRE  wrongly predicted 213 times, from 213 different tickers (2.9% of all tickers)
#       BLLN  wrongly predicted 83 times, from 83 different tickers (1.1% of all tickers)
#       WLTH  wrongly predicted 64 times, from 64 different tickers (0.9% of all tickers)
#        ARX  wrongly predicted 63 times, from 63 different tickers (0.9% of all tickers)
#        WBI  wrongly predicted 62 times, from 62 different tickers (0.8% of all tickers)
#       IYRI  wrongly predicted 62 times, from 62 different tickers (0.8% of all tickers)
#       NUCL  wrongly predicted 61 times, from 61 different tickers (0.8% of all tickers)
#      GLIBK  wrongly predicted 58 times, from 58 different tickers (0.8% of all tickers)
#       EMAT  wrongly predicted 57 times, from 57 different tickers (0.8% of all tickers)
#       HTFL  wrongly predicted 56 times, from 56 different tickers (0.8% of all tickers)
#        MWH  wrongly predicted 51 times, from 51 different tickers (0.7% of all tickers)
#        CBC  wrongly predicted 51 times, from 51 different tickers (0.7% of all tickers)
#      LLYVK  wrongly predicted 47 times, from 47 different tickers (0.6% of all tickers)
#      MYSEW  wrongly predicted 43 times, from 43 different tickers (0.6% of all tickers)
#       ANTA  wrongly predicted 40 times, from 40 different tickers (0.5% of all tickers)
#        SFD  wrongly predicted 39 times, from 39 different tickers (0.5% of all tickers)
#        LGN  wrongly predicted 38 times, from 38 different tickers (0.5% of all tickers)
#        GEV  wrongly predicted 37 times, from 37 different tickers (0.5% of all tickers)
#       EQPT  wrongly predicted 35 times, from 35 different tickers (0.5% of all tickers)
#        RNA  wrongly predicted 35 times, from 35 different tickers (0.5% of all tickers)
