# %%
# %load_ext autoreload
# %autoreload 2
import sys
from pathlib import Path

sys.path.insert(0, '..')  # dataset.py lives one level up, shared across experiment types
import dataset
import matplotlib.colors as mcolors
import matplotlib.pyplot as plt
import model as model_module
import numpy as np
import pandas as pd
import torch
import train as train_module
from sklearn.metrics import confusion_matrix

from investalyze.analysis import encodings
from investalyze.ingest import storage

plt.rcParams['figure.dpi'] = 130
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
TICKERS = 2000  # list[str] of specific tickers, int for a random sample of that many, or None for all
UNIVERSE = None  # name of a universe saved by the ticker selector app (data/universes/<name>.csv); overrides TICKERS when set
EXCLUDE_TICKERS = [
    'LITX',
    'PCG-PD',
    'LIFE',
    'AKRE',
    'BOBS',
    'BKMI',
    'QBTZ',
    'XWIN',
    'SHAZ',
    'OPENL',
    'HOYY',
    'JBS',
    'NSIT',
]  # tickers to always leave out, regardless of TICKERS or UNIVERSE
SEED = 0  # used when TICKERS is an int, and when VALID_METHOD is 'random'
WINDOW_LENGTH = 40
STRIDE = 5

VALID_FRAC = 0.3
VALID_METHOD = 'random'  # 'recent' = time-based (no leakage) / 'random' = random per-window
TEST_N = 1  # always recent: the last N windows of each ticker

ENCODER = encodings.zscore  # swap by hand: RebaseTo100 / RebaseTo1 / encodings.zscore / encodings.minmax
# ENCODER = encodings.minmax  # swap by hand: RebaseTo100 / RebaseTo1 / encodings.zscore / encodings.minmax
BATCH_SIZE = 1024 * 12
EPOCHS = 30
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'

HIDDEN = 64
DROPOUT = 0.05
N_BLOCKS = 10  # residual conv blocks (skip connection per block)
KERNEL_START = 3  # kernel size of the stem conv + first residual blocks
KERNEL_END = 9  # kernel size reached by the last residual block (quadratic ramp, odd sizes only)

LR = 1e-3
LR_FACTOR = 0.5  # ReduceLROnPlateau: multiply lr by this on plateau
LR_PATIENCE = 100  # ReduceLROnPlateau: epochs of no valid_loss improvement before reducing lr
LR_METRIC = 'valid'  # 'valid' normally / 'train' when deliberately overfitting to sanity-check capacity

EARLY_STOP_PATIENCE = 100000000000000000000000  # stop if valid_loss hasn't improved in this many epochs
EVAL_CHECKPOINT = 'valid_loss'  # 'last' / 'train_loss' / 'valid_loss' / 'train_acc' / 'valid_acc'

# %%
DATA_ROOT = Path('../../data')

con = storage.connect(DATA_ROOT, read_only=True)
if UNIVERSE is not None:
    tickers = [t for t in dataset.load_universe(UNIVERSE, DATA_ROOT) if t not in EXCLUDE_TICKERS]
elif isinstance(TICKERS, int):
    tickers = dataset.sample_tickers(con, TICKERS, seed=SEED, exclude=EXCLUDE_TICKERS)
else:
    tickers = TICKERS
series = dataset.get_ohlcv_series(con, tickers, exclude=EXCLUDE_TICKERS)
con.close()
print('tickers used', tickers if tickers is not None else 'ALL')

channels, meta = dataset.build_windows(series, window_length=WINDOW_LENGTH, stride=STRIDE)
print('windows', meta.shape[0], 'across', meta['Ticker'].nunique(), 'tickers')
# Out:
# tickers used ['AA', 'AACB', 'AACIU', 'AAPG', 'AAPL', 'AARD', 'AB', 'ABFL', 'ABLG', 'ABLS', 'ABLVW', 'ABOT', 'ABR-PE', 'ABSI', 'ABTC', 'ABUF', 'ABUS', 'ABVX', 'ACA', 'ACB', 'ACEL', 'ACI', 'ACIW', 'ACLX', 'ACMR', 'ACNT', 'ACOG', 'ACON', 'ACP-PA', 'ACR', 'ACRV', 'ACT', 'ACTG', 'ADAC', 'ADAM', 'ADAMG', 'ADCT', 'ADIL', 'AEAQU', 'AEE', 'AEFC', 'AEG', 'AEIS', 'AEON', 'AESI', 'AFBI', 'AFGD', 'AFGE', 'AFJKU', 'AFL', 'AGH', 'AGI', 'AGNCO', 'AGNT', 'AGRZ', 'AGYS', 'AHL-PF', 'AIBD', 'AIDX', 'AIG', 'AIIOW', 'AIMD', 'AIO', 'AIR', 'AIRG', 'AIRO', 'AIRTP', 'AIUP', 'AIV', 'AKAM', 'AKBA', 'ALAB', 'ALAR', 'ALB-PA', 'ALC', 'ALCO', 'ALDFU', 'ALDX', 'ALHC', 'ALLT', 'ALRS', 'ALSN', 'ALTG', 'ALVO', 'ALVOW', 'AM', 'AMAL', 'AMBA', 'AME', 'AMH-PG', 'AMH-PH', 'AMIX', 'AMJB', 'AMTB', 'AMTM', 'AMYY', 'AMZW', 'ANAB', 'ANG-PD', 'ANGI', 'ANY', 'AON', 'AOUT', 'AP', 'APG', 'API', 'APLD', 'APO-PA', 'APPN', 'APT', 'APTV', 'APVO', 'APWC', 'APXTU', 'AQLT', 'AQN', 'AQST', 'ARAI', 'ARCT', 'ARDC', 'ARDX', 'AREC', 'ARHS', 'ARR-PC', 'ARTL', 'ARVN', 'ARWR', 'ASB', 'ASB-PF', 'ASC', 'ASCI', 'ASG', 'ASH', 'ASIC', 'ASLE', 'ASO', 'ASPCU', 'ASPS', 'ASRT', 'ASUR', 'ASX', 'ASYS', 'ATCH', 'ATCX', 'ATHR', 'ATII', 'ATKR', 'ATMU', 'ATS', 'ATYR', 'AU', 'AUBN', 'AUGO', 'AUID', 'AUSM', 'AVAV', 'AVBH', 'AVD', 'AVNW', 'AVY', 'AWRE', 'AXS-PE', 'AYA', 'AZYY', 'B', 'BA', 'BAC-PM', 'BAC-PP', 'BALY', 'BAM', 'BANFP', 'BAOS', 'BAX', 'BBAR', 'BBCP', 'BBDO', 'BBNX', 'BCAL', 'BCARU', 'BCAX', 'BCGD', 'BCIC', 'BCOR', 'BCPL', 'BCSM', 'BCV', 'BCYC', 'BDL', 'BDMDW', 'BDTX', 'BDX', 'BEAGU', 'BEG', 'BELFB', 'BEPC', 'BEPH', 'BEPJ', 'BFH', 'BFLY', 'BGIN', 'BGL', 'BGM', 'BGMS', 'BGS', 'BGT', 'BHATF', 'BHAV', 'BHB', 'BHE', 'BHFAL', 'BHFAM', 'BHFAN', 'BHFAP', 'BHR', 'BHR-PD', 'BHV', 'BHVN', 'BHYP', 'BIOX', 'BIPJ', 'BJ', 'BK', 'BKE', 'BLBD', 'BLD', 'BLDP', 'BLDX', 'BLRK', 'BLRX', 'BLUX', 'BLX', 'BLZE', 'BLZRW', 'BMEA', 'BMN', 'BMNR', 'BMOP', 'BMRN', 'BNH', 'BNJ', 'BNT', 'BNZI', 'BOH-PB', 'BOKF', 'BOLD', 'BON', 'BOT', 'BPAC', 'BPRN', 'BPYPO', 'BRAG', 'BREE', 'BRKR', 'BRLT', 'BRNS', 'BROS', 'BRTX', 'BRUN', 'BRZE', 'BSBR', 'BSM', 'BSVN', 'BTBT', 'BTCI', 'BTCT', 'BTE', 'BTI', 'BTOT', 'BTQ', 'BTSGU', 'BTX', 'BUD', 'BUFE', 'BULLW', 'BULX', 'BURU', 'BUYO', 'BVAL', 'BW-PA', 'BWA', 'BWBBP', 'BWEN', 'BWNB', 'BXC', 'BYND', 'BYSI', 'CAAS', 'CACI', 'CAF', 'CAFX', 'CAI', 'CALX', 'CANF', 'CAPL', 'CAPN', 'CARD', 'CARE', 'CARL', 'CARR', 'CART', 'CASH', 'CBAT', 'CBFV', 'CBL', 'CBLL', 'CBNA', 'CBRE', 'CBRL', 'CCAP', 'CCB', 'CCCC', 'CCI', 'CCIF', 'CCIXW', 'CCNEP', 'CCRN', 'CCXI', 'CDE', 'CDNA', 'CDNS', 'CDR-PC', 'CDROW', 'CDZI', 'CEF', 'CELUW', 'CENN', 'CEPU', 'CERY', 'CFFN', 'CFG', 'CGABL', 'CGCT', 'CGIC', 'CGNX', 'CGON', 'CGTL', 'CHE', 'CHEC', 'CHI', 'CHKP', 'CHMG', 'CHOW', 'CHPT', 'CHPY', 'CHRI', 'CHRW', 'CHSCO', 'CHSN', 'CHWY', 'CHY', 'CIEN', 'CIG', 'CIG-C', 'CIM', 'CIM-PB', 'CIMN', 'CINF', 'CINGW', 'CIX', 'CLBT', 'CLMT', 'CLOC', 'CLPR', 'CLPT', 'CLSKW', 'CLW', 'CMBO', 'CME', 'CMG', 'CMRC', 'CMRE-PD', 'CMSC', 'CMTV', 'CNCK', 'CNK', 'CNM', 'CNO', 'CNOB', 'CNP', 'CNQ', 'CNS', 'CNXN', 'CODI', 'COF-PJ', 'COHU', 'COIW', 'COLA', 'COLL', 'COLM', 'COOTW', 'COP', 'CORT', 'CORZ', 'CPNS', 'CPRI', 'CPRJ', 'CPS', 'CPSL', 'CPSM', 'CPSU', 'CPSY', 'CPT', 'CRAC', 'CRAI', 'CRAQ', 'CRBD', 'CRBG', 'CRBP', 'CRC', 'CRCD', 'CRD-B', 'CRDU', 'CREX', 'CRMT', 'CRMX', 'CRON', 'CRS', 'CRTO', 'CSAN', 'CSHP', 'CSHR', 'CSIO', 'CSL', 'CSPF', 'CSRE', 'CSTM', 'CTBB', 'CTKB', 'CTLP', 'CTNT', 'CTOR', 'CTRE', 'CTRM', 'CTVA', 'CUBE', 'CUBWW', 'CUE', 'CURB', 'CURR', 'CURV', 'CVGI', 'CVI', 'CVLT', 'CVX', 'CW', 'CWCO', 'CWEN', 'CWH', 'CWT', 'CXE', 'CXT', 'CZNC', 'CZR', 'D', 'DAAQU', 'DAIC', 'DAKT', 'DAL', 'DAR', 'DARE', 'DAVE', 'DCBG', 'DCGO', 'DCI', 'DCOM', 'DCOY', 'DCTH', 'DDDD', 'DDI', 'DEFT', 'DETX', 'DEVS', 'DFDV', 'DFIN', 'DFLI', 'DFTX', 'DGICB', 'DGOC', 'DHC', 'DHCNI', 'DHDG', 'DHF', 'DHSB', 'DIBS', 'DIN', 'DINE', 'DIPS', 'DIT', 'DJCO', 'DJT', 'DLB', 'DLNG', 'DLPN', 'DLR-PJ', 'DLR-PK', 'DLR-PL', 'DLY', 'DMAC', 'DMIIU', 'DNMX', 'DNTH', 'DOCN', 'DOCS', 'DOCU', ' ...
# windows 1144834 across 1848 tickers

# %%
train_mask, valid_mask, test_mask = dataset.split_windows(meta, valid_frac=VALID_FRAC, valid_method=VALID_METHOD, test_n=TEST_N, seed=SEED)

labels, tickers_sorted = dataset.encode_labels(meta, train_mask)
n_classes = len(tickers_sorted)

print('train windows', int(train_mask.sum()), 'valid windows', int(valid_mask.sum()), 'test windows', int(test_mask.sum()))
pd.Series(labels[train_mask]).value_counts().sort_index()
# Out:
# train windows 791709 valid windows 339112 test windows 1792
# 0       2261
# 1         27
# 2       1597
# 3         34
# 4       1311
#         ...
# 1787     223
# 1788      13
# 1789     448
# 1790     753
# 1791     482
# Name: count, Length: 1792, dtype: int64

# %%
X = dataset.encode_windows(channels, ENCODER)
X_train, y_train = X[train_mask], labels[train_mask]
X_valid, y_valid = X[valid_mask], labels[valid_mask]
X_test, y_test = X[test_mask], labels[test_mask]

weights = dataset.class_weights(y_train, n_classes)
train_loader = train_module.make_loader(X_train, y_train, batch_size=BATCH_SIZE, shuffle=True)
valid_loader = train_module.make_loader(X_valid, y_valid, batch_size=BATCH_SIZE, shuffle=False)
test_loader = train_module.make_loader(X_test, y_test, batch_size=BATCH_SIZE, shuffle=False)

# %%
net = model_module.OHLCVClassifierCNN(
    n_channels=5,
    n_classes=n_classes,
    hidden=HIDDEN,
    dropout=DROPOUT,
    n_blocks=N_BLOCKS,
    kernel_start=KERNEL_START,
    kernel_end=KERNEL_END,
).to(DEVICE)
optimizer = torch.optim.Adam(net.parameters(), lr=LR)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=LR_FACTOR, patience=LR_PATIENCE)
history = {'train_loss': [], 'valid_loss': [], 'train_acc': [], 'valid_acc': []}
best = train_module.new_best_tracker()

# %%
net
# Out:
# OHLCVClassifierCNN(
#   (stem): Sequential(
#     (0): Conv1d(5, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout1d(p=0.05, inplace=False)
#   )
#   (blocks): Sequential(
#     (0): _ResConvBlock(
#       (net): Sequential(
#         (0): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#         (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Dropout1d(p=0.05, inplace=False)
#       )
#     )
#     (1): _ResConvBlock(
#       (net): Sequential(
#         (0): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#         (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Dropout1d(p=0.05, inplace=False)
#       )
#     )
#     (2): _ResConvBlock(
#       (net): Sequential(
#         (0): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#         (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Dropout1d(p=0.05, inplace=False)
#       )
#     )
#     (3): _ResConvBlock(
#       (net): Sequential(
#         (0): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#         (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Dropout1d(p=0.05, inplace=False)
#       )
#     )
#     (4): _ResConvBlock(
#       (net): Sequential(
#         (0): Conv1d(64, 64, kernel_size=(5,), stride=(1,), padding=(2,))
#         (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Dropout1d(p=0.05, inplace=False)
#       )
#     )
#     (5): _ResConvBlock(
#       (net): Sequential(
#         (0): Conv1d(64, 64, kernel_size=(5,), stride=(1,), padding=(2,))
#         (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Dropout1d(p=0.05, inplace=False)
#       )
#     )
#     (6): _ResConvBlock(
#       (net): Sequential(
#         (0): Conv1d(64, 64, kernel_size=(7,), stride=(1,), padding=(3,))
#         (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Dropout1d(p=0.05, inplace=False)
#       )
#     )
#     (7): _ResConvBlock(
#       (net): Sequential(
#         (0): Conv1d(64, 64, kernel_size=(7,), stride=(1,), padding=(3,))
#         (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Dropout1d(p=0.05, inplace=False)
#       )
#     )
#     (8): _ResConvBlock(
#       (net): Sequential(
#         (0): Conv1d(64, 64, kernel_size=(9,), stride=(1,), padding=(4,))
#         (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Dropout1d(p=0.05, inplace=False)
#       )
#     )
#   )
#   (last_conv): Sequential(
#     (0): Conv1d(64, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (pool): AdaptiveAvgPool1d(output_size=1)
#   (head): Sequential(
#     (0): Linear(in_features=32, out_features=16, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.05, inplace=False)
#     (3): Linear(in_features=16, out_features=1792, bias=True)
#   )
# )

# %%
CHANGE_LR = False  # set True (and NEW_LR below), then run this cell to change lr mid-training
NEW_LR = 0.1

if CHANGE_LR:
    for g in optimizer.param_groups:
        g['lr'] = NEW_LR
print(f'lr = {optimizer.param_groups[0]["lr"]:.2e}')
# Out:
# lr = 1.00e-03

# %%
print(f'Baseline loss: {np.log(n_classes):.4f} | acc: {1 / n_classes:.4f}')

# re-run this cell (unchanged) to keep training the same net/optimizer for EPOCHS more
history, best = train_module.train_model(
    net,
    train_loader,
    valid_loader,
    optimizer,
    epochs=EPOCHS,
    class_weights=weights,
    n_classes=n_classes,
    device=DEVICE,
    history=history,
    scheduler=scheduler,
    scheduler_metric=LR_METRIC,
    best=best,
    early_stop_patience=EARLY_STOP_PATIENCE,
)
# Out:
# Baseline loss: 7.4911 | acc: 0.0006
# epoch 1/30  train_loss=7.4925 valid_loss=7.4791 train_acc=0.0009 valid_acc=0.0009 lr=1.00e-03 (t:1/1 - v:1/1)
# epoch 2/30  train_loss=7.3677 valid_loss=7.2617 train_acc=0.0013 valid_acc=0.0020 lr=1.00e-03 (t:2/2 - v:2/2)
# epoch 3/30  train_loss=7.1177 valid_loss=7.1633 train_acc=0.0022 valid_acc=0.0025 lr=1.00e-03 (t:3/3 - v:3/3)
# epoch 4/30  train_loss=6.9005 valid_loss=6.8995 train_acc=0.0032 valid_acc=0.0033 lr=1.00e-03 (t:4/4 - v:4/4)
# epoch 5/30  train_loss=6.7615 valid_loss=6.6980 train_acc=0.0038 valid_acc=0.0052 lr=1.00e-03 (t:5/5 - v:5/5)
# epoch 6/30  train_loss=6.6539 valid_loss=6.5816 train_acc=0.0047 valid_acc=0.0058 lr=1.00e-03 (t:6/6 - v:6/6)
# epoch 7/30  train_loss=6.5751 valid_loss=6.5114 train_acc=0.0053 valid_acc=0.0077 lr=1.00e-03 (t:7/7 - v:7/7)
# epoch 8/30  train_loss=6.5088 valid_loss=6.7287 train_acc=0.0067 valid_acc=0.0047 lr=1.00e-03 (t:8/8 - v:7/7)
# epoch 9/30  train_loss=6.4486 valid_loss=6.5734 train_acc=0.0079 valid_acc=0.0066 lr=1.00e-03 (t:9/9 - v:7/7)
# epoch 10/30  train_loss=6.3800 valid_loss=6.6402 train_acc=0.0096 valid_acc=0.0058 lr=1.00e-03 (t:10/10 - v:7/7)
# epoch 11/30  train_loss=6.3218 valid_loss=6.2437 train_acc=0.0114 valid_acc=0.0140 lr=1.00e-03 (t:11/11 - v:11/11)
# epoch 12/30  train_loss=6.2749 valid_loss=6.1779 train_acc=0.0121 valid_acc=0.0154 lr=1.00e-03 (t:12/12 - v:12/12)
# epoch 13/30  train_loss=6.2178 valid_loss=6.2254 train_acc=0.0159 valid_acc=0.0155 lr=1.00e-03 (t:13/13 - v:12/13)
# epoch 14/30  train_loss=6.1761 valid_loss=6.1261 train_acc=0.0180 valid_acc=0.0168 lr=1.00e-03 (t:14/14 - v:14/14)
# epoch 15/30  train_loss=6.1279 valid_loss=6.1818 train_acc=0.0209 valid_acc=0.0164 lr=1.00e-03 (t:15/15 - v:14/14)
# epoch 16/30  train_loss=6.0981 valid_loss=6.0185 train_acc=0.0226 valid_acc=0.0229 lr=1.00e-03 (t:16/16 - v:16/16)
# epoch 17/30  train_loss=6.0679 valid_loss=6.1171 train_acc=0.0255 valid_acc=0.0211 lr=1.00e-03 (t:17/17 - v:16/16)
# epoch 18/30  train_loss=6.0242 valid_loss=6.0315 train_acc=0.0289 valid_acc=0.0277 lr=1.00e-03 (t:18/18 - v:16/18)
# epoch 19/30  train_loss=5.9784 valid_loss=5.9161 train_acc=0.0336 valid_acc=0.0335 lr=1.00e-03 (t:19/19 - v:19/19)
# epoch 20/30  train_loss=5.9540 valid_loss=5.9241 train_acc=0.0358 valid_acc=0.0330 lr=1.00e-03 (t:20/20 - v:19/19)
# epoch 21/30  train_loss=5.9101 valid_loss=5.9315 train_acc=0.0408 valid_acc=0.0352 lr=1.00e-03 (t:21/21 - v:19/21)
# epoch 22/30  train_loss=5.8806 valid_loss=6.3817 train_acc=0.0416 valid_acc=0.0191 lr=1.00e-03 (t:22/22 - v:19/21)
# epoch 23/30  train_loss=5.8388 valid_loss=6.2354 train_acc=0.0465 valid_acc=0.0292 lr=1.00e-03 (t:23/23 - v:19/21)
# epoch 24/30  train_loss=5.8068 valid_loss=5.7602 train_acc=0.0505 valid_acc=0.0531 lr=1.00e-03 (t:24/24 - v:24/24)
# epoch 25/30  train_loss=5.7740 valid_loss=5.7758 train_acc=0.0529 valid_acc=0.0460 lr=1.00e-03 (t:25/25 - v:24/24)
# epoch 26/30  train_loss=5.7308 valid_loss=5.7404 train_acc=0.0580 valid_acc=0.0614 lr=1.00e-03 (t:26/26 - v:26/26)
# epoch 27/30  train_loss=5.6960 valid_loss=5.6875 train_acc=0.0638 valid_acc=0.0553 lr=1.00e-03 (t:27/27 - v:27/26)
# epoch 28/30  train_loss=5.6623 valid_loss=5.6513 train_acc=0.0669 valid_acc=0.0580 lr=1.00e-03 (t:28/28 - v:28/26)
# epoch 29/30  train_loss=5.6365 valid_loss=5.6424 train_acc=0.0690 valid_acc=0.0635 lr=1.00e-03 (t:29/29 - v:29/29)
# epoch 30/30  train_loss=5.6077 valid_loss=5.8748 train_acc=0.0705 valid_acc=0.0552 lr=1.00e-03 (t:30/30 - v:29/29)

# %%
for metric_name, info in best.items():
    print(f'best {metric_name}: epoch {info["epoch"] + 1}  value={info["value"]:.4f}')
# Out:
# best train_loss: epoch 30  value=5.6077
# best valid_loss: epoch 29  value=5.6424
# best train_acc: epoch 30  value=0.0705
# best valid_acc: epoch 29  value=0.0635

# %%
# minmax
# best train_loss: epoch 150  value=3.9503
# best valid_loss: epoch 128  value=4.1035
# best train_acc: epoch 144  value=0.0615
# best valid_acc: epoch 146  value=0.0447

# RebaseTo1
# best train_loss: epoch 150  value=3.8409
# best valid_loss: epoch 137  value=3.9027
# best train_acc: epoch 143  value=0.0495
# best valid_acc: epoch 132  value=0.0463

# zscore
# best train_loss: epoch 150  value=3.6506
# best valid_loss: epoch 146  value=3.8188
# best train_acc: epoch 123  value=0.0850
# best valid_acc: epoch 139  value=0.0730

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))
axes[0].plot(history['train_loss'][10:], label='train')
axes[0].plot(history['valid_loss'][10:], label='valid')
axes[0].set_title('loss')
axes[0].legend()
axes[1].plot(history['train_acc'], label='train')
axes[1].plot(history['valid_acc'], label='valid')
axes[1].axhline(1 / n_classes, color='gray', linestyle='--', label='random baseline')
axes[1].set_title('macro-accuracy')
axes[1].legend()
plt.tight_layout()
plt.show()

# %%
if EVAL_CHECKPOINT != 'last':
    ckpt = best[EVAL_CHECKPOINT]
    net.load_state_dict(ckpt['state'])
    print(f'loaded {EVAL_CHECKPOINT} checkpoint from epoch {ckpt["epoch"] + 1}  value={ckpt["value"]:.4f}')
else:
    print('using last-epoch weights')
# Out:
# loaded valid_loss checkpoint from epoch 29  value=5.6424

# %%
valid_preds, valid_true = train_module.predict(net, valid_loader, DEVICE)
cm_valid = confusion_matrix(valid_true, valid_preds, labels=range(n_classes))
row_sums = cm_valid.sum(axis=1, keepdims=True)
cm_valid_norm = np.divide(cm_valid, row_sums, out=np.zeros_like(cm_valid, dtype=float), where=row_sums != 0)

fig, ax = plt.subplots(figsize=(6, 6))
im = ax.imshow(cm_valid_norm, cmap='viridis', norm=mcolors.PowerNorm(gamma=0.4, vmin=0, vmax=1), interpolation='nearest')
if n_classes <= 40:
    ax.set_xticks(range(n_classes))
    ax.set_xticklabels(tickers_sorted, rotation=90)
    ax.set_yticks(range(n_classes))
    ax.set_yticklabels(tickers_sorted)
else:
    ax.set_xticks([])
    ax.set_yticks([])
ax.set_xlabel('predicted')
ax.set_ylabel('true')
ax.set_title('valid set (row-normalized, gamma=0.4)')
plt.colorbar(im, label='fraction of true class')
plt.tight_layout()
plt.show()

# %%
cm_valid_offdiag = cm_valid.copy()
np.fill_diagonal(cm_valid_offdiag, 0)
i_idx, j_idx = np.nonzero(cm_valid_offdiag)
counts = cm_valid_offdiag[i_idx, j_idx]
order = np.argsort(-counts)[:15]
valid_pairs = [(tickers_sorted[i], tickers_sorted[j], int(c)) for i, j, c in zip(i_idx[order], j_idx[order], counts[order])]
valid_pairs
# Out:
# [('BA', 'AA', 239),
#  ('IP', 'AA', 200),
#  ('PG', 'AA', 179),
#  ('XOM', 'AA', 178),
#  ('FT', 'PPT', 176),
#  ('TRN', 'AA', 169),
#  ('IBM', 'AA', 161),
#  ('MHF', 'PPT', 160),
#  ('CVX', 'AA', 158),
#  ('SPGI', 'AA', 147),
#  ('HAL', 'AA', 135),
#  ('JMM', 'PPT', 134),
#  ('MGEE', 'PPT', 133),
#  ('WY', 'AA', 130),
#  ('BDX', 'AA', 127)]

# %%
preds, y_true = train_module.predict(net, test_loader, DEVICE)
test_acc = (preds == y_true).mean()
test_macro_acc = train_module.macro_accuracy(torch.tensor(preds), torch.tensor(y_true), n_classes)
print(f'test accuracy={test_acc:.3f}  macro-accuracy={test_macro_acc:.3f}')
cm = confusion_matrix(y_true, preds, labels=range(n_classes))
row_sums = cm.sum(axis=1, keepdims=True)
cm_norm = np.divide(cm, row_sums, out=np.zeros_like(cm, dtype=float), where=row_sums != 0)

fig, ax = plt.subplots(figsize=(6, 6))
im = ax.imshow(cm_norm, cmap='viridis', norm=mcolors.PowerNorm(gamma=0.4, vmin=0, vmax=1), interpolation='nearest')
if n_classes <= 40:
    ax.set_xticks(range(n_classes))
    ax.set_xticklabels(tickers_sorted, rotation=90)
    ax.set_yticks(range(n_classes))
    ax.set_yticklabels(tickers_sorted)
else:
    ax.set_xticks([])
    ax.set_yticks([])
ax.set_xlabel('predicted')
ax.set_ylabel('true')
ax.set_title('test set (row-normalized, gamma=0.4)')
plt.colorbar(im, label='fraction of true class')
plt.tight_layout()
plt.show()
# Out:
# test accuracy=0.009  macro-accuracy=0.009

# %%
cm_offdiag = cm.copy()
np.fill_diagonal(cm_offdiag, 0)
i_idx, j_idx = np.nonzero(cm_offdiag)
counts = cm_offdiag[i_idx, j_idx]
order = np.argsort(-counts)[:150]
pairs = [(tickers_sorted[i], tickers_sorted[j], int(c)) for i, j, c in zip(i_idx[order], j_idx[order], counts[order])]
pairs
# Out:
# [('AA', 'BMNR', 1),
#  ('AAPG', 'CARD', 1),
#  ('AAPL', 'BEPC', 1),
#  ('AARD', 'TRDA', 1),
#  ('AB', 'NWN', 1),
#  ('ABFL', 'BVAL', 1),
#  ('ABLG', 'SEPP', 1),
#  ('ABLS', 'DRES', 1),
#  ('ABOT', 'JDVL', 1),
#  ('ABR-PE', 'BMN', 1),
#  ('ABSI', 'RZLV', 1),
#  ('ABTC', 'LU', 1),
#  ('ABUS', 'SYM', 1),
#  ('ABVX', 'AQN', 1),
#  ('ACA', 'JXN', 1),
#  ('ACB', 'SLDE', 1),
#  ('ACEL', 'PBR', 1),
#  ('ACI', 'EOS', 1),
#  ('ACIW', 'NG', 1),
#  ('ACLX', 'BMN', 1),
#  ('ACMR', 'ALC', 1),
#  ('ACNT', 'HOFT', 1),
#  ('ACOG', 'FPH', 1),
#  ('ACON', 'NMG', 1),
#  ('ACP-PA', 'BGM', 1),
#  ('ACR', 'MEGI', 1),
#  ('ACRV', 'USGG', 1),
#  ('ACT', 'UE', 1),
#  ('ACTG', 'GLUE', 1),
#  ('ADAM', 'JXN', 1),
#  ('ADAMG', 'MFAO', 1),
#  ('ADCT', 'INSG', 1),
#  ('ADIL', 'STI', 1),
#  ('AEE', 'BAM', 1),
#  ('AEFC', 'MEGI', 1),
#  ('AEG', 'NEMG', 1),
#  ('AEIS', 'BTCI', 1),
#  ('AEON', 'EAI', 1),
#  ('AESI', 'PSA-PR', 1),
#  ('AFBI', 'GJS', 1),
#  ('AFGD', 'FTNJ', 1),
#  ('AFGE', 'AMYY', 1),
#  ('AFL', 'BTX', 1),
#  ('AGH', 'CRMX', 1),
#  ('AGI', 'KLAG', 1),
#  ('AGNCO', 'PPT', 1),
#  ('AGNT', 'AA', 1),
#  ('AGRZ', 'SIGIP', 1),
#  ('AGYS', 'JXN', 1),
#  ('AHL-PF', 'IDVZ', 1),
#  ('AIBD', 'BULX', 1),
#  ('AIDX', 'AMIX', 1),
#  ('AIG', 'NABL', 1),
#  ('AIMD', 'NAMM', 1),
#  ('AIO', 'RDTE', 1),
#  ('AIR', 'UFOX', 1),
#  ('AIRG', 'TELO', 1),
#  ('AIRO', 'VOYG', 1),
#  ('AIRTP', 'FHN-PC', 1),
#  ('AIUP', 'TSIC', 1),
#  ('AIV', 'WLYB', 1),
#  ('AKAM', 'CNM', 1),
#  ('AKBA', 'ACI', 1),
#  ('ALAB', 'LIF', 1),
#  ('ALAR', 'PSQH', 1),
#  ('ALB-PA', 'RTYY', 1),
#  ('ALC', 'AUGO', 1),
#  ('ALCO', 'PXED', 1),
#  ('ALDX', 'BDTX', 1),
#  ('ALHC', 'BA', 1),
#  ('ALLT', 'NE', 1),
#  ('ALRS', 'ACA', 1),
#  ('ALSN', 'UFOX', 1),
#  ('ALTG', 'TRN', 1),
#  ('ALVO', 'WTTR', 1),
#  ('AM', 'OBDC', 1),
#  ('AMAL', 'DRVN', 1),
#  ('AMBA', 'LRCU', 1),
#  ('AME', 'CSAN', 1),
#  ('AMH-PG', 'GJS', 1),
#  ('AMH-PH', 'MER-PK', 1),
#  ('AMIX', 'SMRF', 1),
#  ('AMJB', 'UFOX', 1),
#  ('AMTB', 'IYRI', 1),
#  ('AMTM', 'DRVN', 1),
#  ('AMYY', 'XLRI', 1),
#  ('AMZW', 'RTYY', 1),
#  ('ANAB', 'USGG', 1),
#  ('ANG-PD', 'FITBI', 1),
#  ('ANGI', 'BBNX', 1),
#  ('ANY', 'VHUB', 1),
#  ('AON', 'BTX', 1),
#  ('AOUT', 'LMRI', 1),
#  ('AP', 'NE', 1),
#  ('APG', 'ISUL', 1),
#  ('API', 'ABSI', 1),
#  ('APLD', 'NBIG', 1),
#  ('APO-PA', 'GILT', 1),
#  ('APPN', 'NE', 1),
#  ('APT', 'CRMX', 1),
#  ('APTV', 'NEM', 1),
#  ('APVO', 'XCUR', 1),
#  ('APWC', 'GJS', 1),
#  ('AQLT', 'BLUX', 1),
#  ('AQN', 'RLTY', 1),
#  ('AQST', 'HNGE', 1),
#  ('ARAI', 'AMIX', 1),
#  ('ARCT', 'AA', 1),
#  ('ARDC', 'NPCT', 1),
#  ('ARDX', 'USGG', 1),
#  ('AREC', 'ZH', 1),
#  ('ARHS', 'BA', 1),
#  ('ARR-PC', 'TMUSI', 1),
#  ('ARTL', 'CHOW', 1),
#  ('ARVN', 'USGG', 1),
#  ('ARWR', 'OBDC', 1),
#  ('ASB', 'RAUS', 1),
#  ('ASB-PF', 'GJS', 1),
#  ('ASC', 'ABSI', 1),
#  ('ASCI', 'GTOC', 1),
#  ('ASG', 'EOS', 1),
#  ('ASH', 'ALB-PA', 1),
#  ('ASIC', 'MXCT', 1),
#  ('ASLE', 'VSNT', 1),
#  ('ASO', 'LTH', 1),
#  ('ASPS', 'SPH', 1),
#  ('ASRT', 'OXM', 1),
#  ('ASUR', 'SFD', 1),
#  ('ASX', 'BTCI', 1),
#  ('ASYS', 'HODU', 1),
#  ('ATCH', 'PRT', 1),
#  ('ATCX', 'AMIX', 1),
#  ('ATHR', 'ORKT', 1),
#  ('ATII', 'EPRX', 1),
#  ('ATKR', 'FBIN', 1),
#  ('ATMU', 'CNQ', 1),
#  ('ATS', 'ROKU', 1),
#  ('ATYR', 'VSNT', 1),
#  ('AU', 'ETHT', 1),
#  ('AUBN', 'FHN-PC', 1),
#  ('AUGO', 'BCSM', 1),
#  ('AUID', 'LMFA', 1),
#  ('AVAV', 'BTQ', 1),
#  ('AVBH', 'LOMA', 1),
#  ('AVD', 'GWH', 1),
#  ('AVNW', 'DTM', 1),
#  ('AVY', 'RTYY', 1),
#  ('AWRE', 'LUXE', 1),
#  ('AXS-PE', 'PPT', 1),
#  ('AYA', 'RY', 1)]

# %%
def worst_predicted(cm_offdiag, top=20):
    fp_counts = cm_offdiag.sum(axis=0)  # column sums: how often each ticker is wrongly predicted
    n_sources = (cm_offdiag > 0).sum(axis=0)  # distinct true tickers wrongly predicted as this one
    order = np.argsort(-fp_counts)[:top]
    return order, fp_counts, n_sources


for name, offdiag in [('valid', cm_valid_offdiag), ('test', cm_offdiag)]:
    order, fp_counts, n_sources = worst_predicted(offdiag)
    print(f'{name}:')
    for idx in order:
        pct_sources = n_sources[idx] / n_classes * 100
        print(
            f'  {tickers_sorted[idx]:>8}  wrongly predicted {int(fp_counts[idx])} times, '
            f'from {int(n_sources[idx])} different tickers ({pct_sources:.1f}% of all tickers)'
        )
    print()
# Out:
# valid:
#         AA  wrongly predicted 16229 times, from 884 different tickers (49.3% of all tickers)
#       BEPC  wrongly predicted 9702 times, from 739 different tickers (41.2% of all tickers)
#       MEGI  wrongly predicted 7858 times, from 786 different tickers (43.9% of all tickers)
#        GHC  wrongly predicted 7334 times, from 716 different tickers (40.0% of all tickers)
#       WLYB  wrongly predicted 7197 times, from 940 different tickers (52.5% of all tickers)
#        FMX  wrongly predicted 7089 times, from 764 different tickers (42.6% of all tickers)
#        SFD  wrongly predicted 6830 times, from 692 different tickers (38.6% of all tickers)
#       IYRI  wrongly predicted 5590 times, from 645 different tickers (36.0% of all tickers)
#         BA  wrongly predicted 4796 times, from 728 different tickers (40.6% of all tickers)
#        PPT  wrongly predicted 4131 times, from 466 different tickers (26.0% of all tickers)
#       RLTY  wrongly predicted 4018 times, from 746 different tickers (41.6% of all tickers)
#       USGG  wrongly predicted 3897 times, from 884 different tickers (49.3% of all tickers)
#        BTX  wrongly predicted 3679 times, from 712 different tickers (39.7% of all tickers)
#        PBR  wrongly predicted 3345 times, from 458 different tickers (25.6% of all tickers)
#        CRS  wrongly predicted 3206 times, from 655 different tickers (36.6% of all tickers)
#       VSNT  wrongly predicted 3012 times, from 712 different tickers (39.7% of all tickers)
#        CNQ  wrongly predicted 2916 times, from 509 different tickers (28.4% of all tickers)
#         UE  wrongly predicted 2788 times, from 583 different tickers (32.5% of all tickers)
#        EOS  wrongly predicted 2657 times, from 476 different tickers (26.6% of all tickers)
#       AUGO  wrongly predicted 2406 times, from 433 different tickers (24.2% of all tickers)
#
# test:
#         AA  wrongly predicted 35 times, from 35 different tickers (2.0% of all tickers)
#       IYRI  wrongly predicted 32 times, from 32 different tickers (1.8% of all tickers)
#       BEPC  wrongly predicted 30 times, from 30 different tickers (1.7% of all tickers)
#       USGG  wrongly predicted 27 times, from 27 different tickers (1.5% of all tickers)
#       UFOX  wrongly predicted 22 times, from 22 different tickers (1.2% of all tickers)
#       MEGI  wrongly predicted 21 times, from 21 different tickers (1.2% of all tickers)
#       CRMX  wrongly predicted 21 times, from 21 different tickers (1.2% of all tickers)
#       BCSM  wrongly predicted 20 times, from 20 different tickers (1.1% of all tickers)
#       WLYB  wrongly predicted 20 times, from 20 different tickers (1.1% of all tickers)
#        ACA  wrongly predicted 20 times, from 20 different tickers (1.1% of all tickers)
#        BTX  wrongly predicted 19 times, from 19 different tickers (1.1% of all tickers)
#         UE  wrongly predicted 17 times, from 17 different tickers (0.9% of all tickers)
#       RDTE  wrongly predicted 17 times, from 17 different tickers (0.9% of all tickers)
#        SFD  wrongly predicted 16 times, from 16 different tickers (0.9% of all tickers)
#       NABL  wrongly predicted 16 times, from 16 different tickers (0.9% of all tickers)
#       BTCI  wrongly predicted 15 times, from 15 different tickers (0.8% of all tickers)
#        GJS  wrongly predicted 14 times, from 14 different tickers (0.8% of all tickers)
#         BA  wrongly predicted 14 times, from 14 different tickers (0.8% of all tickers)
#        CRS  wrongly predicted 14 times, from 14 different tickers (0.8% of all tickers)
#       AMIX  wrongly predicted 14 times, from 14 different tickers (0.8% of all tickers)
