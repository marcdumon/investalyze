# %%
# %load_ext autoreload
# %autoreload 2
import sys
from pathlib import Path

import matplotlib.colors as mcolors
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn.metrics import confusion_matrix

sys.path.insert(0, '..')  # dataset.py lives one level up, shared across sector/industry notebooks
import dataset
import xgb_train

from investalyze.analysis import encodings
from investalyze.ingest import storage

plt.rcParams['figure.dpi'] = 130

# %%
TICKERS = 5000  # list[str] of specific tickers, int for a random sample of that many, or None for all
UNIVERSE = None  # name of a universe saved by the screener app (data/universes/<name>.csv); overrides TICKERS when set
EXCLUDE_TICKERS = []  # tickers to always leave out, regardless of TICKERS or UNIVERSE

LABEL_COLUMN = 'Sector'  # 'Sector' or 'Industry', from the companies table

SEED = 0  # used when TICKERS is an int, and when VALID_METHOD is 'random'
WINDOW_LENGTH = 60
STRIDE = 45

VALID_FRAC = 0.3
VALID_METHOD = 'random'  # 'recent' = time-based (no leakage) / 'random' = random per-window
TEST_N = 2  # always recent: the last N windows of each ticker

ENCODER = encodings.RebaseTo1  # swap by hand: RebaseTo100 / RebaseTo1 / encodings.zscore / encodings.minmax

N_ESTIMATORS = 500  # boosting rounds (upper bound; early stopping picks the best)
MAX_DEPTH = 12
LEARNING_RATE = 0.30
EARLY_STOPPING_ROUNDS = 10  # stop if valid mlogloss hasn't improved in this many rounds
N_JOBS = -1

# %%
DATA_ROOT = Path('../../data')

con = storage.connect(DATA_ROOT, read_only=True)
if UNIVERSE is not None:
    tickers = [t for t in dataset.load_universe(UNIVERSE, DATA_ROOT) if t not in EXCLUDE_TICKERS]
elif isinstance(TICKERS, int):
    tickers = dataset.sample_tickers(con, TICKERS, seed=SEED, exclude=EXCLUDE_TICKERS)
else:
    tickers = TICKERS
series = dataset.get_ohlcv_series(con, tickers, exclude=EXCLUDE_TICKERS)
ticker_labels = dataset.get_ticker_labels(con, LABEL_COLUMN)
con.close()
print('tickers used', tickers if tickers is not None else 'ALL')

channels, meta = dataset.build_windows(series, window_length=WINDOW_LENGTH, stride=STRIDE)
channels, meta = dataset.attach_labels(channels, meta, ticker_labels)
n_tickers, n_labels = meta['Ticker'].nunique(), meta['label'].nunique()
print(f"windows {meta.shape[0]} across {n_tickers} tickers and {n_labels} sectors")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# tickers used ['A', 'AA', 'AACB', 'AACG', 'AACI', 'AACOU', 'AACPU', 'AAEQ', 'AAL', 'AAME', 'AAMI', 'AAON', 'AAP', 'AAPG', 'AAPL', 'AAPW', 'AARD', 'AAT', 'AB', 'ABBV', 'ABCB', 'ABCL', 'ABEO', 'ABEV', 'ABLD', 'ABLG', 'ABLV', 'ABNB', 'ABNG', 'ABOS', 'ABOT', 'ABR-PE', 'ABSI', 'ABT', 'ABTS', 'ABUF', 'ABUS', 'ABVC', 'ABVE', 'ABVEW', 'ABVX', 'ABXB', 'ABXL', 'ACA', 'ACAA', 'ACAAU', 'ACAD', 'ACB', 'ACCL', 'ACCS', 'ACDC', 'ACEL', 'ACEP', 'ACFN', 'ACGCU', 'ACGL', 'ACGLN', 'ACGLO', 'ACGR', 'ACH', 'ACHR', 'ACIU', 'ACIW', 'ACLO', 'ACLX', 'ACM', 'ACN', 'ACNT', 'ACOG', 'ACON', 'ACONW', 'ACP-PA', 'ACR-PD', 'ACRS', 'ACT', 'ACTS', 'ACTU', 'ACU', 'ACV', 'ACVA', 'AD', 'ADAC', 'ADACU', 'ADAG', 'ADAMG', 'ADAMI', 'ADAMM', 'ADAMN', 'ADAMZ', 'ADC-PA', 'ADGM', 'ADM', 'ADMA', 'ADNT', 'ADP', 'ADPT', 'ADSE', 'ADSEW', 'ADTN', 'ADUR', 'ADV', 'ADX', 'AEAQ', 'AEAQU', 'AEBI', 'AEC', 'AEE', 'AEF', 'AEFC', 'AEG', 'AEHR', 'AEIS', 'AEM', 'AEMD', 'AENT', 'AEO', 'AEON', 'AEP', 'AER', 'AERT', 'AERTW', 'AEVA', 'AEXA', 'AFB', 'AFCG', 'AFG', 'AFGB', 'AFGC', 'AFGD', 'AFGE', 'AFJKU', 'AFL', 'AFRM', 'AGAE', 'AGBK', 'AGCO', 'AGEN', 'AGGS', 'AGH', 'AGI', 'AGIO', 'AGIQ', 'AGM', 'AGM-A', 'AGM-PD', 'AGM-PE', 'AGM-PG', 'AGMH', 'AGNC', 'AGNCL', 'AGNCN', 'AGNCP', 'AGNCZ', 'AGNT', 'AGO', 'AGPU', 'AGYS', 'AHCO', 'AHL-PE', 'AHL-PF', 'AHMA', 'AHR', 'AHT', 'AHT-PF', 'AIAI', 'AIB', 'AIBD', 'AIBU', 'AIDX', 'AIFF', 'AIFU', 'AIHS', 'AII', 'AIIO', 'AIMD', 'AIN', 'AINT', 'AIO', 'AIOT', 'AIP', 'AIR', 'AIRE', 'AIRG', 'AIRI', 'AIRJ', 'AIRJW', 'AIRO', 'AIRS', 'AISP', 'AIT', 'AIUP', 'AIXC', 'AJG', 'AKA', 'AKAN', 'AKR', 'AKRE', 'AKTX', 'ALAB', 'ALAR', 'ALBT', 'ALC', 'ALCY', 'ALDF', 'ALDFU', 'ALDFW', 'ALDX', 'ALEC', 'ALF', 'ALG', 'ALGN', 'ALGT', 'ALH', 'ALIS', 'ALISU', 'ALL', 'ALL-PH', 'ALLE', 'ALLO', 'ALLT', 'ALM', 'ALMR', 'ALNY', 'ALOT', 'ALOV', 'ALOY', 'ALP', 'ALPS', 'ALRG', 'ALRM', 'ALTG', 'ALUB', 'ALVO', 'ALVOW', 'ALX', 'AMA', 'AMBP', 'AMBQ', 'AMBR', 'AMCI', 'AMCR', 'AMCX', 'AMD', 'AME', 'AMG', 'AMGN', 'AMH-PH', 'AMIX', 'AMKR', 'AMN', 'AMODW', 'AMPH', 'AMPL', 'AMPX', 'AMPY', 'AMR', 'AMRX', 'AMRZ', 'AMS', 'AMTB', 'AMTX', 'AMWD', 'AMX', 'AMYY', 'AMZE', 'AMZW', 'AN', 'ANDE', 'ANDG', 'ANEL', 'ANET', 'ANG-PD', 'ANGH', 'ANGX', 'ANIK', 'ANIP', 'ANIX', 'ANL', 'ANNA', 'ANNX', 'ANPA', 'ANRO', 'ANTA', 'AOMN', 'AOMR', 'AORT', 'AOS', 'AOSL', 'AOUT', 'APA', 'APAC', 'APADU', 'APAM', 'APD', 'APEI', 'APG', 'APH', 'API', 'APLD', 'APM', 'APO', 'APO-PA', 'APOG', 'APP', 'APPS', 'APRB', 'APT', 'APVO', 'APXTW', 'APYX', 'AQB', 'AQMS', 'AQN', 'AQNB', 'AQST', 'AR', 'ARAI', 'ARAY', 'ARBB', 'ARBK', 'ARCC', 'ARCI', 'ARCIU', 'ARCLU', 'ARCT', 'ARDC', 'ARDT', 'ARDX', 'ARE', 'AREN', 'ARES', 'ARES-PB', 'ARHS', 'ARI', 'ARIS', 'ARM', 'AROC', 'AROW', 'ARQQ', 'ARQT', 'ARRY', 'ARTC', 'ARTCU', 'ARTNA', 'ARTV', 'ARTY', 'ARW', 'ARX', 'ARXS', 'AS', 'ASA', 'ASAN', 'ASB', 'ASB-PF', 'ASBPW', 'ASCE', 'ASCI', 'ASGI', 'ASGM', 'ASH', 'ASIC', 'ASIX', 'ASM', 'ASMU', 'ASND', 'ASPC', 'ASPCU', 'ASPI', 'ASPSW', 'ASR', 'ASRT', 'ASRV', 'ASST', 'ASTC', 'ASTI', 'ASTL', 'ASTLW', 'ASUR', 'ASX', 'ATAI', 'ATEC', 'ATEX', 'ATH-PA', 'ATH-PB', 'ATH-PD', 'ATH-PE', 'ATHE', 'ATHR', 'ATII', 'ATIIW', 'ATLC', 'ATLCL', 'ATLCZ', 'ATLN', 'ATLX', 'ATMU', 'ATNI', 'ATOM', 'ATOS', 'ATR', 'ATRO', 'ATXG', 'ATYR', 'AU', 'AUB-PA', 'AUGP', 'AUID', 'AUNA', 'AUR', 'AURE', 'AUROW', 'AUTL', 'AUUD', 'AVAV', 'AVB', 'AVBC', 'AVBH', 'AVBP', 'AVGO', 'AVIR', 'AVK', 'AVNT', 'AVNW', 'AVOS', 'AVPT', 'AVR', 'AVT', 'AVTM', 'AVTR', 'AVTX', 'AVX', 'AVXL', 'AVXX', 'AVY', 'AWI', 'AWK', 'AWRE', 'AX', 'AXG', 'AXIA', 'AXIL', 'AXIN', 'AXINU', 'AXP', 'AXR', 'AXS', 'AXS-PE', 'AXSM', 'AXTA', 'AXTI', 'AYA', 'AYTU', 'AZ', 'AZI', 'AZN', 'AZTR', 'BA-PA', 'BABA', 'BABO', 'BABU', 'BAC-PB', 'BAC-PK', 'BAC-PL', 'BAC-PM', 'BACC', 'BACCU', 'BAER', 'BAFN', 'BAI', 'BAIV', 'BAK', 'BALL', 'BALQ', 'BALY', 'BANC', 'BANC-PF', 'BAND', 'BANF', 'BANFP', 'BANL', 'BANR', 'BANX', 'BAOS', 'BATL', 'BATRK', 'BAYA', 'BB', 'BBAI', 'BBB', 'BBBY', 'BBCQU', 'BBDC', 'BBGI', 'BBLG', 'BBN', 'BBNX', 'BBOT', 'BBSI', 'BBUC', 'BBW', 'BBWI', ' ...
# windows 301672 across 3653 tickers and 11 sectors

# %%
train_mask, valid_mask, test_mask = dataset.split_windows(
    meta, valid_frac=VALID_FRAC, valid_method=VALID_METHOD, test_n=TEST_N, seed=SEED
)

labels, class_names = dataset.encode_labels(meta, train_mask, label_col='label')
n_classes = len(class_names)

print('train windows', int(train_mask.sum()), 'valid windows', int(valid_mask.sum()), 'test windows', int(test_mask.sum()))
pd.Series(labels[train_mask]).value_counts().sort_index()
# Out:
# train windows 203674 valid windows 87223 test windows 7012
# 0     11478
# 1      7846
# 2     22059
# 3     10012
# 4     11844
# 5     46570
# 6     25580
# 7     27422
# 8     10865
# 9     24071
# 10     5927
# Name: count, dtype: int64

# %%
X = dataset.encode_windows(channels, ENCODER)
X_flat = dataset.flatten_windows(X)
X_train, y_train = X_flat[train_mask], labels[train_mask]
X_valid, y_valid = X_flat[valid_mask], labels[valid_mask]
X_test, y_test = X_flat[test_mask], labels[test_mask]

weights = dataset.class_weights(y_train, n_classes)
sample_weight = weights[y_train]

# %%
clf = xgb.XGBClassifier(
    n_estimators=N_ESTIMATORS,
    max_depth=MAX_DEPTH,
    learning_rate=LEARNING_RATE,
    tree_method='hist',
    early_stopping_rounds=EARLY_STOPPING_ROUNDS,
    eval_metric='mlogloss',
    n_jobs=N_JOBS,
)
clf.fit(X_train, y_train, sample_weight=sample_weight, eval_set=[(X_valid, y_valid)], verbose=True)
print('best iteration', clf.best_iteration, '/', N_ESTIMATORS)
# Out:
# [0]	validation_0-mlogloss:2.36665
# [1]	validation_0-mlogloss:2.34435
# [2]	validation_0-mlogloss:2.32837
# [3]	validation_0-mlogloss:2.31602
# [4]	validation_0-mlogloss:2.30640
# [5]	validation_0-mlogloss:2.29937
# [6]	validation_0-mlogloss:2.29308
# [7]	validation_0-mlogloss:2.28702
# [8]	validation_0-mlogloss:2.28244
# [9]	validation_0-mlogloss:2.27797
# [10]	validation_0-mlogloss:2.27470
# [11]	validation_0-mlogloss:2.27178
# [12]	validation_0-mlogloss:2.26813
# [13]	validation_0-mlogloss:2.26504
# [14]	validation_0-mlogloss:2.26249
# [15]	validation_0-mlogloss:2.26029
# [16]	validation_0-mlogloss:2.25763
# [17]	validation_0-mlogloss:2.25449
# [18]	validation_0-mlogloss:2.25314
# [19]	validation_0-mlogloss:2.25069
# [20]	validation_0-mlogloss:2.24802
# [21]	validation_0-mlogloss:2.24590
# [22]	validation_0-mlogloss:2.24432
# [23]	validation_0-mlogloss:2.24197
# [24]	validation_0-mlogloss:2.24024
# [25]	validation_0-mlogloss:2.23850
# [26]	validation_0-mlogloss:2.23792
# [27]	validation_0-mlogloss:2.23627
# [28]	validation_0-mlogloss:2.23379
# [29]	validation_0-mlogloss:2.23251
# [30]	validation_0-mlogloss:2.23144
# [31]	validation_0-mlogloss:2.23043
# [32]	validation_0-mlogloss:2.22912
# [33]	validation_0-mlogloss:2.22767
# [34]	validation_0-mlogloss:2.22645
# [35]	validation_0-mlogloss:2.22616
# [36]	validation_0-mlogloss:2.22569
# [37]	validation_0-mlogloss:2.22480
# [38]	validation_0-mlogloss:2.22352
# [39]	validation_0-mlogloss:2.22323
# [40]	validation_0-mlogloss:2.22236
# [41]	validation_0-mlogloss:2.22236
# [42]	validation_0-mlogloss:2.22210
# [43]	validation_0-mlogloss:2.22179
# [44]	validation_0-mlogloss:2.22098
# [45]	validation_0-mlogloss:2.22110
# [46]	validation_0-mlogloss:2.22084
# [47]	validation_0-mlogloss:2.22084
# [48]	validation_0-mlogloss:2.22079
# [49]	validation_0-mlogloss:2.22102
# [50]	validation_0-mlogloss:2.22099
# [51]	validation_0-mlogloss:2.22115
# [52]	validation_0-mlogloss:2.22168
# [53]	validation_0-mlogloss:2.22202
# [54]	validation_0-mlogloss:2.22267
# [55]	validation_0-mlogloss:2.22273
# [56]	validation_0-mlogloss:2.22333
# [57]	validation_0-mlogloss:2.22411
# [58]	validation_0-mlogloss:2.22441
# best iteration 48 / 500

# %%
valid_logloss = clf.evals_result()['validation_0']['mlogloss']
plt.figure(figsize=(8, 4))
plt.plot(valid_logloss)
plt.axvline(clf.best_iteration, color='gray', linestyle='--', label='best iteration')
plt.xlabel('boosting round')
plt.ylabel('valid mlogloss')
plt.legend()
plt.tight_layout()
plt.show()

# %%
valid_preds = clf.predict(X_valid)
valid_true = y_valid
valid_macro_acc = xgb_train.macro_accuracy(valid_preds, valid_true, n_classes)
print(f'valid accuracy={(valid_preds == valid_true).mean():.3f}  macro-accuracy={valid_macro_acc:.3f}')

cm_valid = confusion_matrix(valid_true, valid_preds, labels=range(n_classes))
row_sums = cm_valid.sum(axis=1, keepdims=True)
cm_valid_norm = np.divide(cm_valid, row_sums, out=np.zeros_like(cm_valid, dtype=float), where=row_sums != 0)

fig, ax = plt.subplots(figsize=(6, 6))
im = ax.imshow(cm_valid_norm, cmap='viridis', norm=mcolors.PowerNorm(gamma=0.4, vmin=0, vmax=1), interpolation='nearest')
if n_classes <= 40:
    ax.set_xticks(range(n_classes))
    ax.set_xticklabels(class_names, rotation=90)
    ax.set_yticks(range(n_classes))
    ax.set_yticklabels(class_names)
else:
    ax.set_xticks([])
    ax.set_yticks([])
ax.set_xlabel('predicted')
ax.set_ylabel('true')
ax.set_title('valid set (row-normalized, gamma=0.4)')
plt.colorbar(im, label='fraction of true class')
plt.tight_layout()
plt.show()
# Out:
# valid accuracy=0.235  macro-accuracy=0.149

# %%
cm_valid_offdiag = cm_valid.copy()
np.fill_diagonal(cm_valid_offdiag, 0)
i_idx, j_idx = np.nonzero(cm_valid_offdiag)
counts = cm_valid_offdiag[i_idx, j_idx]
order = np.argsort(-counts)[:15]
valid_pairs = [(class_names[i], class_names[j], int(c)) for i, j, c in zip(i_idx[order], j_idx[order], counts[order])]
valid_pairs
# Out:
# [('Industrials', 'Financial Services', 2808),
#  ('Financial Services', 'Industrials', 2660),
#  ('Technology', 'Healthcare', 2344),
#  ('Consumer Cyclical', 'Industrials', 1929),
#  ('Real Estate', 'Financial Services', 1918),
#  ('Technology', 'Industrials', 1887),
#  ('Healthcare', 'Technology', 1876),
#  ('Consumer Cyclical', 'Financial Services', 1765),
#  ('Healthcare', 'Industrials', 1713),
#  ('Industrials', 'Healthcare', 1678),
#  ('Industrials', 'Consumer Cyclical', 1661),
#  ('Consumer Cyclical', 'Healthcare', 1600),
#  ('Financial Services', 'Consumer Cyclical', 1539),
#  ('Technology', 'Consumer Cyclical', 1482),
#  ('Technology', 'Financial Services', 1479)]

# %%
preds, y_true = clf.predict(X_test), y_test
test_acc = (preds == y_true).mean()
test_macro_acc = xgb_train.macro_accuracy(preds, y_true, n_classes)
print(f'test accuracy={test_acc:.3f}  macro-accuracy={test_macro_acc:.3f}')

cm = confusion_matrix(y_true, preds, labels=range(n_classes))
row_sums = cm.sum(axis=1, keepdims=True)
cm_norm = np.divide(cm, row_sums, out=np.zeros_like(cm, dtype=float), where=row_sums != 0)

fig, ax = plt.subplots(figsize=(6, 6))
im = ax.imshow(cm_norm, cmap='viridis', norm=mcolors.PowerNorm(gamma=0.4, vmin=0, vmax=1), interpolation='nearest')
if n_classes <= 40:
    ax.set_xticks(range(n_classes))
    ax.set_xticklabels(class_names, rotation=90)
    ax.set_yticks(range(n_classes))
    ax.set_yticklabels(class_names)
else:
    ax.set_xticks([])
    ax.set_yticks([])
ax.set_xlabel('predicted')
ax.set_ylabel('true')
ax.set_title('test set (row-normalized, gamma=0.4)')
plt.colorbar(im, label='fraction of true class')
plt.tight_layout()
plt.show()
# Out:
# test accuracy=0.247  macro-accuracy=0.156

# %%
cm_offdiag = cm.copy()
np.fill_diagonal(cm_offdiag, 0)
i_idx, j_idx = np.nonzero(cm_offdiag)
counts = cm_offdiag[i_idx, j_idx]
order = np.argsort(-counts)[:15]
pairs = [(class_names[i], class_names[j], int(c)) for i, j, c in zip(i_idx[order], j_idx[order], counts[order])]
pairs
# Out:
# [('Technology', 'Healthcare', 308),
#  ('Healthcare', 'Technology', 241),
#  ('Industrials', 'Healthcare', 231),
#  ('Real Estate', 'Financial Services', 194),
#  ('Consumer Cyclical', 'Healthcare', 178),
#  ('Healthcare', 'Consumer Cyclical', 175),
#  ('Industrials', 'Technology', 157),
#  ('Financial Services', 'Industrials', 150),
#  ('Healthcare', 'Industrials', 145),
#  ('Financial Services', 'Consumer Cyclical', 137),
#  ('Financial Services', 'Healthcare', 134),
#  ('Consumer Cyclical', 'Technology', 128),
#  ('Basic Materials', 'Healthcare', 118),
#  ('Financial Services', 'Technology', 118),
#  ('Technology', 'Consumer Cyclical', 117)]

# %%
def worst_predicted(cm_offdiag, top=10):
    fp_counts = cm_offdiag.sum(axis=0)  # column sums: how often each class is wrongly predicted
    n_sources = (cm_offdiag > 0).sum(axis=0)  # distinct true classes wrongly predicted as this one
    order = np.argsort(-fp_counts)[:top]
    return order, fp_counts, n_sources


for name, offdiag in [('valid', cm_valid_offdiag), ('test', cm_offdiag)]:
    order, fp_counts, n_sources = worst_predicted(offdiag)
    print(f'{name}:')
    for idx in order:
        pct_sources = n_sources[idx] / n_classes * 100
        print(
            f'  {class_names[idx]:<28}  wrongly predicted {int(fp_counts[idx])} times, '
            f'from {int(n_sources[idx])} different classes ({pct_sources:.1f}% of all classes)'
        )
    print()
# Out:
# valid:
#   Financial Services            wrongly predicted 14618 times, from 10 different classes (90.9% of all classes)
#   Industrials                   wrongly predicted 12471 times, from 10 different classes (90.9% of all classes)
#   Healthcare                    wrongly predicted 10198 times, from 10 different classes (90.9% of all classes)
#   Consumer Cyclical             wrongly predicted 9019 times, from 10 different classes (90.9% of all classes)
#   Technology                    wrongly predicted 8570 times, from 10 different classes (90.9% of all classes)
#   Real Estate                   wrongly predicted 3180 times, from 10 different classes (90.9% of all classes)
#   Energy                        wrongly predicted 3149 times, from 10 different classes (90.9% of all classes)
#   Basic Materials               wrongly predicted 1822 times, from 10 different classes (90.9% of all classes)
#   Utilities                     wrongly predicted 1791 times, from 10 different classes (90.9% of all classes)
#   Consumer Defensive            wrongly predicted 1382 times, from 10 different classes (90.9% of all classes)
#
# test:
#   Healthcare                    wrongly predicted 1282 times, from 10 different classes (90.9% of all classes)
#   Technology                    wrongly predicted 918 times, from 10 different classes (90.9% of all classes)
#   Consumer Cyclical             wrongly predicted 769 times, from 10 different classes (90.9% of all classes)
#   Industrials                   wrongly predicted 762 times, from 10 different classes (90.9% of all classes)
#   Financial Services            wrongly predicted 646 times, from 10 different classes (90.9% of all classes)
#   Energy                        wrongly predicted 399 times, from 10 different classes (90.9% of all classes)
#   Basic Materials               wrongly predicted 165 times, from 10 different classes (90.9% of all classes)
#   Real Estate                   wrongly predicted 142 times, from 10 different classes (90.9% of all classes)
#   Consumer Defensive            wrongly predicted 98 times, from 10 different classes (90.9% of all classes)
#   Utilities                     wrongly predicted 54 times, from 9 different classes (81.8% of all classes)
